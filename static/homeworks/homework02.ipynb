# %% [markdown]
# # Introduction to Artificial Intelligence - Homework Assignment 02 (20pts.)

# %% [markdown]
# - NETID:
# - Name: Example Solution
#
# This assignment covers the following topics:
# - Decision Trees
# - Hidden Markov Models
# - Bayesian Reasoning
#
# Please complete all sections. Some questions will require written answers, while others will involve coding. Be sure to run your code cells to verify your solutions.

# %% [markdown]
# ## Task 0: Collecting Suspect Statements (0 pts)

# %% [markdown]
# ### *Story Progression*
#
# After contacting the police with your findings, they created a list of suspects:
#
# * Professor Theisen
# * Olivia Zino
# * Tom Lohman
# * Sophia Noonan
# * Jack Mangione
# * Cesar Cervera
#
# They were able to get statements from 4 of the 6 suspects, but unfortunately they need your help tracking down the other two. We need to gather more evidence if we're going to be able to figure out who's alibi doesn't hold up. You need to visit the two remaining suspects and collect their statements to get the needed evidence.

# %% [markdown]
# ### *Task Description*
#
# 1. Visit the two remaining suspects to collect their statements. Only one team member needs to visit each suspect, so feel free to divy up the work. The available times to pick up the suspects (TAs) statements are listed below.
#
#
#
# *   Jack Mangione: 5:00 - 7:00 on Monday and Wednesday in the CSE Commons
# *   Olivia Zino: 2:00 - 4:00 Sunday and 2:00 - 3:00 Monday and Wednesday in the Inno Lounge
#
#
#
#
# 2. Once you've collected them, add them to the suspect data json files.
#
# *   Hint: I wonder if an LLM like ChatGPT-4o could turn a picture of the statements into the json files you need?

# %% [markdown]
# ## Task 1: Load and create the necessary data (2 pts)

# %% [markdown]
# ### *Story Progression*
#
# After getting in contact with the Theisen-Floyd Estate the police have collected data for past costume parties they've thrown. Turns out there's been a lot of them. They've gathered data on the movement and activity patterns of the aliases.
#
# Thinking back to class you realize that if you have all of this alias data, you could probably structure this as a supervised learning problem, and a classification task! We could compare our suspect data against the alias data, treating it as the ground-truth, and see if any of the suspects line up against the aliases!

# %% [markdown]
# ### *Task Description*
#
# 1. Load alias statements into a dictionary called "alias_data" with the format:
#
# ```
# {
#     "alias_name": [
#         {"suspect_statement": [...]}
#     ]
# }
# ```
#
# 2. Add the suspect statements to the suspect data json files.
#
# 3. Load the suspect data into a dictionary called "suspect_data" with the format:
#
# ```
# {
#     "suspect_name":
#         {"suspect_statement": [...], "gps_data": [...], "witness_statements": {...}}
# }
# ```
#
# * Note: starting data is available at [Homework 02 Data](https://drive.google.com/drive/folders/1k9LND_mc5sTLemg77nAOHPq0qLYpEcJM?usp=sharing)

# %% [markdown]
# ### *Code Implemetation*

# %%
### Mount google drive ###
from google.colab import drive
drive.mount('/content/drive')

# %%
### Import necessary libraries ###
import os
import numpy as np
import json

from typing import List, Dict, Any
from collections import defaultdict
import pprint

# Load in Alias Statement Data (all you have to do is define the path to your alias training statements)
alias_data_dir = '/content/drive/MyDrive/Intro To AI/Homeworks/HW02/Alias Training Statements'      # Path to alias statement data
alias_data = defaultdict(list)                                                # Dictionary to store alias statements, format: {alias: [list of entries per alias]}

for filename in os.listdir(alias_data_dir):                            # For all files in the alias statement directory:
  if filename.endswith(".json"):                                       #     If file is .json format, then:
    file_path = os.path.join(alias_data_dir, filename)                 #        Build the full file path string

    with open(file_path, 'r') as f:                                    #        Open file at file_path:
        data = json.load(f)                                            #            Load json content into a dict (hint: json.load() is very useful here)
        alias_data[data['name']].append(data)                          #            Store data in alias_data dict


# Load suspect statement data (all you have to do is define the path to your suspect statement data)
suspect_data_dir = '/content/drive/MyDrive/Intro To AI/Homeworks/HW02/Suspect Statements'           # Path to suspect statement data
suspect_data = {}                                                             # Dictionary to store suspect statement data, format:  {suspect name: {json data}}

for filename in os.listdir(suspect_data_dir):                          # For all files in the suspect data directory:
    if filename.endswith(".json"):                                     #     If file is .json format, then:
      with open(os.path.join(suspect_data_dir, filename), 'r') as f:   #         Open file at file_path
          data = json.load(f)                                          #         Load json file content into a dict
          suspect_name = data['name']                                  #         Get suspects name
          suspect_data[suspect_name] = data                            #         Store suspects data in suspect_data dict

# Print Resulting Data
print("ALIAS DATA")
pprint.pprint(alias_data)

print("SUSCPECT DATA")
pprint.pprint(suspect_data)

# %% [markdown]
# #### BONUS CODE CELL WITH ALIAS DATA AND SUSPECT DATA ALREADY DEFINED
#
# If you are struggling with the creation and loading in of json data, the dictionaries are manually defined below

# %%
# manually defined dictionaries for alias and suspect data
alias_data = {'Colonel Mustard': [{'suspect_statement': [{'time': '19:00 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '19:10 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '19:20 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '19:30 PM', 'location': 'Bathroom', 'activity': 'Looking in drawers'}, {'time': '19:40 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Rinsing a glass carefully'}, {'time': '20:00 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Rinsing a glass carefully'}, {'time': '20:20 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '20:40 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '20:50 PM', 'location': 'Bathroom', 'activity': 'Polishing household items'}, {'time': '21:00 PM', 'location': 'Living Room', 'activity': 'Retrieving items from storage'}, {'time': '21:10 PM', 'location': 'Living Room', 'activity': 'Tying decorative knots'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Rinsing a glass carefully'}, {'time': '21:30 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '21:40 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:50 PM', 'location': 'Dining Room', 'activity': 'Taking her dog for a walk'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Bragging about their Birkin'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Living Room', 'activity': 'Rinsing a glass carefully'}, {'time': '19:10 PM', 'location': 'Study', 'activity': 'Chatting with guests'}, {'time': '19:20 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '19:30 PM', 'location': 'Study', 'activity': 'Rinsing a glass carefully'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Bragging about their Birkin'}, {'time': '19:50 PM', 'location': 'Living Room', 'activity': 'Rinsing a glass carefully'}, {'time': '20:00 PM', 'location': 'Bathroom', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:10 PM', 'location': 'Living Room', 'activity': 'Reading a novel quietly'}, {'time': '20:20 PM', 'location': 'Study', 'activity': 'Tampering with drinks'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:50 PM', 'location': 'Kitchen', 'activity': 'Bragging about their Birkin'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:10 PM', 'location': 'Living Room', 'activity': 'Polishing household items'}, {'time': '21:20 PM', 'location': 'Bathroom', 'activity': 'Tampering with drinks'}, {'time': '21:30 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:50 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '22:00 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '19:10 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '19:20 PM', 'location': 'Kitchen', 'activity': 'Tampering with drinks'}, {'time': '19:30 PM', 'location': 'Kitchen', 'activity': 'Serving drinks and chatting with guests'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Rinsing a glass carefully'}, {'time': '19:50 PM', 'location': 'Study', 'activity': 'Speaking in a high-pitched voice'}, {'time': '20:00 PM', 'location': 'Dining Room', 'activity': 'Rinsing a glass carefully'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Rinsing a glass carefully'}, {'time': '20:20 PM', 'location': 'Dining Room', 'activity': 'Rinsing a glass carefully'}, {'time': '20:30 PM', 'location': 'Kitchen', 'activity': 'Inspecting wine bottles'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:50 PM', 'location': 'Study', 'activity': 'Serving drinks and chatting with guests'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Rinsing a glass carefully'}, {'time': '21:10 PM', 'location': 'Study', 'activity': 'Inspecting wine bottles'}, {'time': '21:20 PM', 'location': 'Living Room', 'activity': 'Rinsing a glass carefully'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '21:40 PM', 'location': 'Kitchen', 'activity': 'Rinsing a glass carefully'}, {'time': '21:50 PM', 'location': 'Pantry', 'activity': 'Serving drinks and chatting with guests'}, {'time': '22:00 PM', 'location': 'Kitchen', 'activity': 'Observing guests from afar'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Tying decorative knots'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Dining Room', 'activity': 'Taking her dog for a walk'}, {'time': '19:10 PM', 'location': 'Kitchen', 'activity': 'Chatting with guests'}, {'time': '19:20 PM', 'location': 'Pantry', 'activity': 'Serving drinks and chatting with guests'}, {'time': '19:30 PM', 'location': 'Kitchen', 'activity': 'Swapping drinks unnoticed'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '19:50 PM', 'location': 'Kitchen', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:00 PM', 'location': 'Dining Room', 'activity': 'Inspecting a family heirloom'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:20 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:30 PM', 'location': 'Living Room', 'activity': 'Washing up after handling items'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '20:50 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '21:20 PM', 'location': 'Kitchen', 'activity': 'Inspecting wine bottles'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '21:50 PM', 'location': 'Living Room', 'activity': 'Reading warning labels'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Retrieving items from storage'}, {'time': '22:10 PM', 'location': 'Study', 'activity': 'Inspecting wine bottles'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Dining Room', 'activity': 'Returning to mingle with guests'}, {'time': '19:10 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '19:20 PM', 'location': 'Bathroom', 'activity': 'Inspecting wine bottles'}, {'time': '19:30 PM', 'location': 'Living Room', 'activity': 'Rinsing a glass carefully'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '19:50 PM', 'location': 'Study', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:00 PM', 'location': 'Dining Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '20:20 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}, {'time': '20:30 PM', 'location': 'Kitchen', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '20:50 PM', 'location': 'Kitchen', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:00 PM', 'location': 'Pantry', 'activity': 'Tampering with drinks'}, {'time': '21:10 PM', 'location': 'Kitchen', 'activity': 'Rinsing a glass carefully'}, {'time': '21:20 PM', 'location': 'Pantry', 'activity': 'Whittling a stick'}, {'time': '21:30 PM', 'location': 'Kitchen', 'activity': 'Inspecting wine bottles'}, {'time': '21:40 PM', 'location': 'Pantry', 'activity': 'Tampering with drinks'}, {'time': '21:50 PM', 'location': 'Kitchen', 'activity': 'Tampering with drinks'}, {'time': '22:00 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '22:10 PM', 'location': 'Living Room', 'activity': 'Looking in drawers'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '19:10 PM', 'location': 'Study', 'activity': 'Serving drinks and chatting with guests'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '19:30 PM', 'location': 'Living Room', 'activity': 'Rinsing a glass carefully'}, {'time': '19:40 PM', 'location': 'Bathroom', 'activity': 'Bringing in the shopping'}, {'time': '19:50 PM', 'location': 'Bathroom', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:00 PM', 'location': 'Living Room', 'activity': 'Reading warning labels'}, {'time': '20:10 PM', 'location': 'Living Room', 'activity': 'Tying decorative knots'}, {'time': '20:20 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:30 PM', 'location': 'Study', 'activity': 'Tampering with drinks'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:50 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '21:00 PM', 'location': 'Study', 'activity': 'Inspecting a family heirloom'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:20 PM', 'location': 'Kitchen', 'activity': 'Tampering with drinks'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Opening a safe'}, {'time': '21:50 PM', 'location': 'Dining Room', 'activity': 'Inflating balloons'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '22:10 PM', 'location': 'Bathroom', 'activity': 'Rinsing a glass carefully'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '19:10 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '19:30 PM', 'location': 'Study', 'activity': 'Serving drinks and chatting with guests'}, {'time': '19:40 PM', 'location': 'Study', 'activity': 'Rinsing a glass carefully'}, {'time': '19:50 PM', 'location': 'Study', 'activity': 'Tampering with drinks'}, {'time': '20:00 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:20 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}, {'time': '20:50 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}, {'time': '21:10 PM', 'location': 'Kitchen', 'activity': 'Rinsing a glass carefully'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}, {'time': '21:30 PM', 'location': 'Study', 'activity': 'Rinsing a glass carefully'}, {'time': '21:40 PM', 'location': 'Dining Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '21:50 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '22:10 PM', 'location': 'Living Room', 'activity': 'Opening letters'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '19:10 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '19:20 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '19:30 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '19:40 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}, {'time': '20:00 PM', 'location': 'Kitchen', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Looking in drawers'}, {'time': '20:20 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}, {'time': '20:40 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '20:50 PM', 'location': 'Living Room', 'activity': 'Rinsing a glass carefully'}, {'time': '21:00 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:20 PM', 'location': 'Living Room', 'activity': 'Rinsing a glass carefully'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Washing up after handling items'}, {'time': '21:40 PM', 'location': 'Study', 'activity': 'Inspecting wine bottles'}, {'time': '21:50 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Chatting with guests'}, {'time': '22:10 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '19:10 PM', 'location': 'Living Room', 'activity': 'Speaking in a high-pitched voice'}, {'time': '19:20 PM', 'location': 'Study', 'activity': 'Serving drinks and chatting with guests'}, {'time': '19:30 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Bringing in the shopping'}, {'time': '19:50 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:00 PM', 'location': 'Study', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:10 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '20:20 PM', 'location': 'Bathroom', 'activity': 'Taking her dog for a walk'}, {'time': '20:30 PM', 'location': 'Bathroom', 'activity': 'Rinsing a glass carefully'}, {'time': '20:40 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:50 PM', 'location': 'Dining Room', 'activity': 'Rinsing a glass carefully'}, {'time': '21:00 PM', 'location': 'Kitchen', 'activity': 'Rinsing a glass carefully'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:20 PM', 'location': 'Kitchen', 'activity': 'Inspecting wine bottles'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:40 PM', 'location': 'Study', 'activity': 'Tampering with drinks'}, {'time': '21:50 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '22:00 PM', 'location': 'Dining Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Taking her dog for a walk'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '19:10 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '19:20 PM', 'location': 'Kitchen', 'activity': 'Swapping drinks unnoticed'}, {'time': '19:30 PM', 'location': 'Pantry', 'activity': 'Tampering with drinks'}, {'time': '19:40 PM', 'location': 'Kitchen', 'activity': 'Rinsing a glass carefully'}, {'time': '19:50 PM', 'location': 'Pantry', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:00 PM', 'location': 'Kitchen', 'activity': 'Opening a safe'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}, {'time': '20:20 PM', 'location': 'Dining Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:30 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:40 PM', 'location': 'Bathroom', 'activity': 'Peeling an orange'}, {'time': '20:50 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '21:00 PM', 'location': 'Bathroom', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:10 PM', 'location': 'Living Room', 'activity': 'Retrieving items from storage'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Bringing in the shopping'}, {'time': '21:30 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '21:50 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Returning to mingle with guests'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '19:10 PM', 'location': 'Bathroom', 'activity': 'Swapping drinks unnoticed'}, {'time': '19:20 PM', 'location': 'Bathroom', 'activity': 'Peeling an orange'}, {'time': '19:30 PM', 'location': 'Living Room', 'activity': 'Rinsing a glass carefully'}, {'time': '19:40 PM', 'location': 'Living Room', 'activity': 'Rinsing a glass carefully'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Rinsing a glass carefully'}, {'time': '20:00 PM', 'location': 'Dining Room', 'activity': 'Rinsing a glass carefully'}, {'time': '20:10 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}, {'time': '20:20 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}, {'time': '20:30 PM', 'location': 'Living Room', 'activity': 'Rinsing a glass carefully'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '20:50 PM', 'location': 'Dining Room', 'activity': 'Rinsing a glass carefully'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Opening a safe'}, {'time': '21:30 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '21:50 PM', 'location': 'Bathroom', 'activity': 'Serving drinks and chatting with guests'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '22:10 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Dining Room', 'activity': 'Rinsing a glass carefully'}, {'time': '19:10 PM', 'location': 'Kitchen', 'activity': 'Raising a painting'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '19:30 PM', 'location': 'Study', 'activity': 'Rinsing a glass carefully'}, {'time': '19:40 PM', 'location': 'Living Room', 'activity': 'Ripping wippets'}, {'time': '19:50 PM', 'location': 'Living Room', 'activity': 'Speaking in a high-pitched voice'}, {'time': '20:00 PM', 'location': 'Study', 'activity': 'Tampering with drinks'}, {'time': '20:10 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '20:20 PM', 'location': 'Dining Room', 'activity': 'Bragging about their Birkin'}, {'time': '20:30 PM', 'location': 'Study', 'activity': 'Rinsing a glass carefully'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Rinsing a glass carefully'}, {'time': '20:50 PM', 'location': 'Dining Room', 'activity': 'Rinsing a glass carefully'}, {'time': '21:00 PM', 'location': 'Study', 'activity': 'Washing up after handling items'}, {'time': '21:10 PM', 'location': 'Living Room', 'activity': 'Whittling a stick'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}, {'time': '21:30 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}, {'time': '21:40 PM', 'location': 'Dining Room', 'activity': 'Opening a safe'}, {'time': '21:50 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '22:00 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Returning to mingle with guests'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Living Room', 'activity': 'Rinsing a glass carefully'}, {'time': '19:10 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}, {'time': '19:30 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '19:50 PM', 'location': 'Living Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '20:00 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}, {'time': '20:10 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '20:20 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:30 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Rinsing a glass carefully'}, {'time': '20:50 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}, {'time': '21:00 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '21:10 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '21:20 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '21:30 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Rinsing a glass carefully'}, {'time': '21:50 PM', 'location': 'Study', 'activity': 'Inspecting wine bottles'}, {'time': '22:00 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '22:10 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Living Room', 'activity': 'Tying decorative knots'}, {'time': '19:10 PM', 'location': 'Dining Room', 'activity': 'Tying decorative knots'}, {'time': '19:20 PM', 'location': 'Kitchen', 'activity': 'Talking about skeet shooting'}, {'time': '19:30 PM', 'location': 'Dining Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '19:50 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '20:00 PM', 'location': 'Dining Room', 'activity': 'Rinsing a glass carefully'}, {'time': '20:10 PM', 'location': 'Living Room', 'activity': 'Rinsing a glass carefully'}, {'time': '20:20 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '20:30 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '20:40 PM', 'location': 'Living Room', 'activity': 'Observing guests from afar'}, {'time': '20:50 PM', 'location': 'Dining Room', 'activity': 'Returning to mingle with guests'}, {'time': '21:00 PM', 'location': 'Study', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:10 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Chatting with guests'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '21:50 PM', 'location': 'Living Room', 'activity': 'Opening letters'}, {'time': '22:00 PM', 'location': 'Study', 'activity': 'Tampering with drinks'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '19:10 PM', 'location': 'Living Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:20 PM', 'location': 'Study', 'activity': 'Serving drinks and chatting with guests'}, {'time': '19:30 PM', 'location': 'Study', 'activity': 'Reading warning labels'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Rinsing a glass carefully'}, {'time': '20:00 PM', 'location': 'Kitchen', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Rinsing a glass carefully'}, {'time': '20:20 PM', 'location': 'Dining Room', 'activity': 'Rinsing a glass carefully'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Raising a painting'}, {'time': '20:40 PM', 'location': 'Kitchen', 'activity': 'Tampering with drinks'}, {'time': '20:50 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}, {'time': '21:00 PM', 'location': 'Living Room', 'activity': 'Peeling an orange'}, {'time': '21:10 PM', 'location': 'Living Room', 'activity': 'Talking about skeet shooting'}, {'time': '21:20 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Polishing household items'}, {'time': '21:40 PM', 'location': 'Dining Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '21:50 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}, {'time': '22:00 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Bragging about their Birkin'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Living Room', 'activity': 'Rinsing a glass carefully'}, {'time': '19:10 PM', 'location': 'Study', 'activity': 'Reading warning labels'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Reorganizing books and materials'}, {'time': '19:30 PM', 'location': 'Dining Room', 'activity': 'Reading a novel quietly'}, {'time': '19:40 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '19:50 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '20:00 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}, {'time': '20:20 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:30 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '20:50 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:00 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Opening letters'}, {'time': '21:20 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '21:30 PM', 'location': 'Bathroom', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Opening a safe'}, {'time': '21:50 PM', 'location': 'Bathroom', 'activity': 'Serving drinks and chatting with guests'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Serving drinks and chatting with guests'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Dining Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '19:10 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '19:20 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '19:30 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '19:50 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:00 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:10 PM', 'location': 'Study', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:20 PM', 'location': 'Living Room', 'activity': 'Speaking in a high-pitched voice'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:50 PM', 'location': 'Study', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '21:10 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:20 PM', 'location': 'Bathroom', 'activity': 'Inspecting wine bottles'}, {'time': '21:30 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '21:40 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '21:50 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Bragging about their Birkin'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '19:10 PM', 'location': 'Living Room', 'activity': 'Reading a novel quietly'}, {'time': '19:20 PM', 'location': 'Study', 'activity': 'Rinsing a glass carefully'}, {'time': '19:30 PM', 'location': 'Living Room', 'activity': 'Rinsing a glass carefully'}, {'time': '19:40 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '19:50 PM', 'location': 'Living Room', 'activity': 'Chatting with guests'}, {'time': '20:00 PM', 'location': 'Bathroom', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:10 PM', 'location': 'Living Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '20:20 PM', 'location': 'Living Room', 'activity': 'Reorganizing books and materials'}, {'time': '20:30 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:40 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:50 PM', 'location': 'Dining Room', 'activity': 'Returning to mingle with guests'}, {'time': '21:00 PM', 'location': 'Study', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:10 PM', 'location': 'Living Room', 'activity': 'Rinsing a glass carefully'}, {'time': '21:20 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Speaking in a high-pitched voice'}, {'time': '21:50 PM', 'location': 'Bathroom', 'activity': 'Serving drinks and chatting with guests'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '22:10 PM', 'location': 'Living Room', 'activity': 'Opening letters'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '19:10 PM', 'location': 'Living Room', 'activity': 'Returning to mingle with guests'}, {'time': '19:20 PM', 'location': 'Bathroom', 'activity': 'Swapping drinks unnoticed'}, {'time': '19:30 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '19:40 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Rinsing a glass carefully'}, {'time': '20:00 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:10 PM', 'location': 'Study', 'activity': 'Retrieving items from storage'}, {'time': '20:20 PM', 'location': 'Study', 'activity': 'Reading warning labels'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Chatting with guests'}, {'time': '20:50 PM', 'location': 'Study', 'activity': 'Serving drinks and chatting with guests'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Returning to mingle with guests'}, {'time': '21:20 PM', 'location': 'Study', 'activity': 'Tampering with drinks'}, {'time': '21:30 PM', 'location': 'Living Room', 'activity': 'Whittling a stick'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '21:50 PM', 'location': 'Bathroom', 'activity': 'Tampering with drinks'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '22:10 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Dining Room', 'activity': 'Rinsing a glass carefully'}, {'time': '19:10 PM', 'location': 'Study', 'activity': 'Serving drinks and chatting with guests'}, {'time': '19:20 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '19:30 PM', 'location': 'Bathroom', 'activity': 'Rinsing a glass carefully'}, {'time': '19:40 PM', 'location': 'Living Room', 'activity': 'Retrieving items from storage'}, {'time': '19:50 PM', 'location': 'Bathroom', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:00 PM', 'location': 'Bathroom', 'activity': 'Inspecting wine bottles'}, {'time': '20:10 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:20 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Raising a painting'}, {'time': '20:50 PM', 'location': 'Kitchen', 'activity': 'Serving drinks and chatting with guests'}, {'time': '21:00 PM', 'location': 'Pantry', 'activity': 'Washing up after handling items'}, {'time': '21:10 PM', 'location': 'Kitchen', 'activity': 'Serving drinks and chatting with guests'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '21:30 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '21:50 PM', 'location': 'Living Room', 'activity': 'Rinsing a glass carefully'}, {'time': '22:00 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '22:10 PM', 'location': 'Living Room', 'activity': 'Observing guests from afar'}]}], 'Mr. Green': [{'suspect_statement': [{'time': '19:00 PM', 'location': 'Pantry', 'activity': 'Ripping wippets'}, {'time': '19:10 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '19:20 PM', 'location': 'Pantry', 'activity': 'Serving drinks and chatting with guests'}, {'time': '19:30 PM', 'location': 'Pantry', 'activity': 'Reading warning labels'}, {'time': '19:40 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '19:50 PM', 'location': 'Pantry', 'activity': 'Bragging about their Birkin'}, {'time': '20:00 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Inspecting a family heirloom'}, {'time': '20:20 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '20:30 PM', 'location': 'Pantry', 'activity': 'Observing guests from afar'}, {'time': '20:40 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '20:50 PM', 'location': 'Kitchen', 'activity': 'Speaking in a high-pitched voice'}, {'time': '21:00 PM', 'location': 'Pantry', 'activity': 'Looking in drawers'}, {'time': '21:10 PM', 'location': 'Kitchen', 'activity': 'Inflating balloons'}, {'time': '21:20 PM', 'location': 'Pantry', 'activity': 'Looking in drawers'}, {'time': '21:30 PM', 'location': 'Kitchen', 'activity': 'Inflating balloons'}, {'time': '21:40 PM', 'location': 'Dining Room', 'activity': 'Reading warning labels'}, {'time': '21:50 PM', 'location': 'Dining Room', 'activity': 'Reading a novel quietly'}, {'time': '22:00 PM', 'location': 'Kitchen', 'activity': 'Bragging about their Birkin'}, {'time': '22:10 PM', 'location': 'Pantry', 'activity': 'Inflating balloons'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '19:10 PM', 'location': 'Pantry', 'activity': 'Ripping wippets'}, {'time': '19:20 PM', 'location': 'Kitchen', 'activity': 'Speaking in a high-pitched voice'}, {'time': '19:30 PM', 'location': 'Pantry', 'activity': 'Ripping wippets'}, {'time': '19:40 PM', 'location': 'Pantry', 'activity': 'Speaking in a high-pitched voice'}, {'time': '19:50 PM', 'location': 'Pantry', 'activity': 'Speaking in a high-pitched voice'}, {'time': '20:00 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '20:10 PM', 'location': 'Pantry', 'activity': 'Rinsing a glass carefully'}, {'time': '20:20 PM', 'location': 'Kitchen', 'activity': 'Inflating balloons'}, {'time': '20:30 PM', 'location': 'Pantry', 'activity': 'Inflating balloons'}, {'time': '20:40 PM', 'location': 'Kitchen', 'activity': 'Inflating balloons'}, {'time': '20:50 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Speaking in a high-pitched voice'}, {'time': '21:10 PM', 'location': 'Kitchen', 'activity': 'Polishing household items'}, {'time': '21:20 PM', 'location': 'Pantry', 'activity': 'Ripping wippets'}, {'time': '21:30 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '21:40 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '21:50 PM', 'location': 'Kitchen', 'activity': 'Observing guests from afar'}, {'time': '22:00 PM', 'location': 'Dining Room', 'activity': 'Speaking in a high-pitched voice'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Looking in drawers'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '19:10 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '19:20 PM', 'location': 'Kitchen', 'activity': 'Speaking in a high-pitched voice'}, {'time': '19:30 PM', 'location': 'Pantry', 'activity': 'Ripping wippets'}, {'time': '19:40 PM', 'location': 'Pantry', 'activity': 'Reading warning labels'}, {'time': '19:50 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '20:00 PM', 'location': 'Pantry', 'activity': 'Observing guests from afar'}, {'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Speaking in a high-pitched voice'}, {'time': '20:20 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '20:30 PM', 'location': 'Kitchen', 'activity': 'Inflating balloons'}, {'time': '20:40 PM', 'location': 'Pantry', 'activity': 'Ripping wippets'}, {'time': '20:50 PM', 'location': 'Kitchen', 'activity': 'Raising a painting'}, {'time': '21:00 PM', 'location': 'Kitchen', 'activity': 'Opening letters'}, {'time': '21:10 PM', 'location': 'Pantry', 'activity': 'Speaking in a high-pitched voice'}, {'time': '21:20 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '21:30 PM', 'location': 'Pantry', 'activity': 'Ripping wippets'}, {'time': '21:40 PM', 'location': 'Kitchen', 'activity': 'Opening letters'}, {'time': '21:50 PM', 'location': 'Pantry', 'activity': 'Polishing household items'}, {'time': '22:00 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '22:10 PM', 'location': 'Pantry', 'activity': 'Speaking in a high-pitched voice'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '19:10 PM', 'location': 'Pantry', 'activity': 'Bragging about their Birkin'}, {'time': '19:20 PM', 'location': 'Kitchen', 'activity': 'Tampering with drinks'}, {'time': '19:30 PM', 'location': 'Kitchen', 'activity': 'Speaking in a high-pitched voice'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Speaking in a high-pitched voice'}, {'time': '19:50 PM', 'location': 'Study', 'activity': 'Inflating balloons'}, {'time': '20:00 PM', 'location': 'Study', 'activity': 'Reading warning labels'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Looking in drawers'}, {'time': '20:20 PM', 'location': 'Kitchen', 'activity': 'Inflating balloons'}, {'time': '20:30 PM', 'location': 'Pantry', 'activity': 'Speaking in a high-pitched voice'}, {'time': '20:40 PM', 'location': 'Kitchen', 'activity': 'Inflating balloons'}, {'time': '20:50 PM', 'location': 'Pantry', 'activity': 'Tampering with drinks'}, {'time': '21:00 PM', 'location': 'Kitchen', 'activity': 'Inflating balloons'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Inflating balloons'}, {'time': '21:20 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Ripping wippets'}, {'time': '21:40 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '21:50 PM', 'location': 'Pantry', 'activity': 'Reading warning labels'}, {'time': '22:00 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '22:10 PM', 'location': 'Pantry', 'activity': 'Inflating balloons'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Opening letters'}, {'time': '19:10 PM', 'location': 'Pantry', 'activity': 'Inflating balloons'}, {'time': '19:20 PM', 'location': 'Pantry', 'activity': 'Inflating balloons'}, {'time': '19:30 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '19:40 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Looking in drawers'}, {'time': '20:00 PM', 'location': 'Kitchen', 'activity': 'Inflating balloons'}, {'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '20:20 PM', 'location': 'Dining Room', 'activity': 'Reading warning labels'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Inflating balloons'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Reading warning labels'}, {'time': '20:50 PM', 'location': 'Dining Room', 'activity': 'Reading a novel quietly'}, {'time': '21:00 PM', 'location': 'Study', 'activity': 'Ripping wippets'}, {'time': '21:10 PM', 'location': 'Study', 'activity': 'Reading warning labels'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Inflating balloons'}, {'time': '21:30 PM', 'location': 'Study', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Looking in drawers'}, {'time': '21:50 PM', 'location': 'Bathroom', 'activity': 'Talking about skeet shooting'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Speaking in a high-pitched voice'}, {'time': '22:10 PM', 'location': 'Bathroom', 'activity': 'Looking in drawers'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Pantry', 'activity': 'Serving drinks and chatting with guests'}, {'time': '19:10 PM', 'location': 'Kitchen', 'activity': 'Tampering with drinks'}, {'time': '19:20 PM', 'location': 'Pantry', 'activity': 'Ripping wippets'}, {'time': '19:30 PM', 'location': 'Kitchen', 'activity': 'Speaking in a high-pitched voice'}, {'time': '19:40 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '19:50 PM', 'location': 'Kitchen', 'activity': 'Speaking in a high-pitched voice'}, {'time': '20:00 PM', 'location': 'Dining Room', 'activity': 'Inflating balloons'}, {'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Whittling a stick'}, {'time': '20:20 PM', 'location': 'Pantry', 'activity': 'Looking in drawers'}, {'time': '20:30 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '20:40 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '20:50 PM', 'location': 'Pantry', 'activity': 'Reading warning labels'}, {'time': '21:00 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '21:10 PM', 'location': 'Pantry', 'activity': 'Rinsing a glass carefully'}, {'time': '21:20 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Inflating balloons'}, {'time': '21:40 PM', 'location': 'Dining Room', 'activity': 'Reading warning labels'}, {'time': '21:50 PM', 'location': 'Kitchen', 'activity': 'Speaking in a high-pitched voice'}, {'time': '22:00 PM', 'location': 'Pantry', 'activity': 'Reading warning labels'}, {'time': '22:10 PM', 'location': 'Kitchen', 'activity': 'Inflating balloons'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '19:10 PM', 'location': 'Pantry', 'activity': 'Ripping wippets'}, {'time': '19:20 PM', 'location': 'Pantry', 'activity': 'Speaking in a high-pitched voice'}, {'time': '19:30 PM', 'location': 'Kitchen', 'activity': 'Peeling an orange'}, {'time': '19:40 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Reading warning labels'}, {'time': '20:00 PM', 'location': 'Kitchen', 'activity': 'Tying decorative knots'}, {'time': '20:10 PM', 'location': 'Pantry', 'activity': 'Speaking in a high-pitched voice'}, {'time': '20:20 PM', 'location': 'Pantry', 'activity': 'Inflating balloons'}, {'time': '20:30 PM', 'location': 'Pantry', 'activity': 'Returning to mingle with guests'}, {'time': '20:40 PM', 'location': 'Kitchen', 'activity': 'Observing guests from afar'}, {'time': '20:50 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '21:00 PM', 'location': 'Pantry', 'activity': 'Inflating balloons'}, {'time': '21:10 PM', 'location': 'Kitchen', 'activity': 'Speaking in a high-pitched voice'}, {'time': '21:20 PM', 'location': 'Pantry', 'activity': 'Retrieving items from storage'}, {'time': '21:30 PM', 'location': 'Kitchen', 'activity': 'Rinsing a glass carefully'}, {'time': '21:40 PM', 'location': 'Pantry', 'activity': 'Ripping wippets'}, {'time': '21:50 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '22:00 PM', 'location': 'Dining Room', 'activity': 'Speaking in a high-pitched voice'}, {'time': '22:10 PM', 'location': 'Living Room', 'activity': 'Inflating balloons'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '19:10 PM', 'location': 'Pantry', 'activity': 'Looking in drawers'}, {'time': '19:20 PM', 'location': 'Kitchen', 'activity': 'Inflating balloons'}, {'time': '19:30 PM', 'location': 'Dining Room', 'activity': 'Looking in drawers'}, {'time': '19:40 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:00 PM', 'location': 'Kitchen', 'activity': 'Tampering with drinks'}, {'time': '20:10 PM', 'location': 'Pantry', 'activity': 'Looking in drawers'}, {'time': '20:20 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Inflating balloons'}, {'time': '20:40 PM', 'location': 'Living Room', 'activity': 'Looking in drawers'}, {'time': '20:50 PM', 'location': 'Living Room', 'activity': 'Ripping wippets'}, {'time': '21:00 PM', 'location': 'Study', 'activity': 'Looking in drawers'}, {'time': '21:10 PM', 'location': 'Living Room', 'activity': 'Inflating balloons'}, {'time': '21:20 PM', 'location': 'Study', 'activity': 'Ripping wippets'}, {'time': '21:30 PM', 'location': 'Study', 'activity': 'Looking in drawers'}, {'time': '21:40 PM', 'location': 'Study', 'activity': 'Speaking in a high-pitched voice'}, {'time': '21:50 PM', 'location': 'Dining Room', 'activity': 'Reading warning labels'}, {'time': '22:00 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '22:10 PM', 'location': 'Kitchen', 'activity': 'Rinsing a glass carefully'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '19:10 PM', 'location': 'Pantry', 'activity': 'Speaking in a high-pitched voice'}, {'time': '19:20 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '19:30 PM', 'location': 'Pantry', 'activity': 'Reading warning labels'}, {'time': '19:40 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '19:50 PM', 'location': 'Pantry', 'activity': 'Inflating balloons'}, {'time': '20:00 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '20:20 PM', 'location': 'Pantry', 'activity': 'Bringing in the shopping'}, {'time': '20:30 PM', 'location': 'Kitchen', 'activity': 'Inflating balloons'}, {'time': '20:40 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '20:50 PM', 'location': 'Pantry', 'activity': 'Speaking in a high-pitched voice'}, {'time': '21:00 PM', 'location': 'Kitchen', 'activity': 'Serving drinks and chatting with guests'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Looking in drawers'}, {'time': '21:20 PM', 'location': 'Living Room', 'activity': 'Speaking in a high-pitched voice'}, {'time': '21:30 PM', 'location': 'Living Room', 'activity': 'Bringing in the shopping'}, {'time': '21:40 PM', 'location': 'Study', 'activity': 'Tampering with drinks'}, {'time': '21:50 PM', 'location': 'Study', 'activity': 'Looking in drawers'}, {'time': '22:00 PM', 'location': 'Study', 'activity': 'Bragging about their Birkin'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Looking in drawers'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '19:10 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '19:20 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '19:30 PM', 'location': 'Kitchen', 'activity': 'Reorganizing books and materials'}, {'time': '19:40 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '19:50 PM', 'location': 'Pantry', 'activity': 'Washing up after handling items'}, {'time': '20:00 PM', 'location': 'Kitchen', 'activity': 'Returning to mingle with guests'}, {'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '20:20 PM', 'location': 'Kitchen', 'activity': 'Polishing household items'}, {'time': '20:30 PM', 'location': 'Pantry', 'activity': 'Ripping wippets'}, {'time': '20:40 PM', 'location': 'Pantry', 'activity': 'Speaking in a high-pitched voice'}, {'time': '20:50 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '21:00 PM', 'location': 'Pantry', 'activity': 'Inflating balloons'}, {'time': '21:10 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '21:20 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '21:30 PM', 'location': 'Kitchen', 'activity': 'Speaking in a high-pitched voice'}, {'time': '21:40 PM', 'location': 'Pantry', 'activity': 'Reading warning labels'}, {'time': '21:50 PM', 'location': 'Pantry', 'activity': 'Looking in drawers'}, {'time': '22:00 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '22:10 PM', 'location': 'Pantry', 'activity': 'Reading warning labels'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Pantry', 'activity': 'Reorganizing books and materials'}, {'time': '19:10 PM', 'location': 'Kitchen', 'activity': 'Polishing household items'}, {'time': '19:20 PM', 'location': 'Pantry', 'activity': 'Inflating balloons'}, {'time': '19:30 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '19:40 PM', 'location': 'Pantry', 'activity': 'Reading warning labels'}, {'time': '19:50 PM', 'location': 'Kitchen', 'activity': 'Speaking in a high-pitched voice'}, {'time': '20:00 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Opening a safe'}, {'time': '20:20 PM', 'location': 'Living Room', 'activity': 'Inflating balloons'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '20:40 PM', 'location': 'Kitchen', 'activity': 'Inspecting wine bottles'}, {'time': '20:50 PM', 'location': 'Kitchen', 'activity': 'Polishing household items'}, {'time': '21:00 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Ripping wippets'}, {'time': '21:20 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '21:30 PM', 'location': 'Pantry', 'activity': 'Returning to mingle with guests'}, {'time': '21:40 PM', 'location': 'Pantry', 'activity': 'Reorganizing books and materials'}, {'time': '21:50 PM', 'location': 'Kitchen', 'activity': 'Speaking in a high-pitched voice'}, {'time': '22:00 PM', 'location': 'Pantry', 'activity': 'Ripping wippets'}, {'time': '22:10 PM', 'location': 'Pantry', 'activity': 'Reading warning labels'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Pantry', 'activity': 'Speaking in a high-pitched voice'}, {'time': '19:10 PM', 'location': 'Kitchen', 'activity': 'Speaking in a high-pitched voice'}, {'time': '19:20 PM', 'location': 'Pantry', 'activity': 'Reading warning labels'}, {'time': '19:30 PM', 'location': 'Kitchen', 'activity': 'Serving drinks and chatting with guests'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '19:50 PM', 'location': 'Study', 'activity': 'Ripping wippets'}, {'time': '20:00 PM', 'location': 'Study', 'activity': 'Looking in drawers'}, {'time': '20:10 PM', 'location': 'Study', 'activity': 'Reading warning labels'}, {'time': '20:20 PM', 'location': 'Dining Room', 'activity': 'Chatting with guests'}, {'time': '20:30 PM', 'location': 'Study', 'activity': 'Looking in drawers'}, {'time': '20:40 PM', 'location': 'Study', 'activity': 'Reading warning labels'}, {'time': '20:50 PM', 'location': 'Dining Room', 'activity': 'Ripping wippets'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Reading warning labels'}, {'time': '21:10 PM', 'location': 'Study', 'activity': 'Looking in drawers'}, {'time': '21:20 PM', 'location': 'Living Room', 'activity': 'Looking in drawers'}, {'time': '21:30 PM', 'location': 'Bathroom', 'activity': 'Speaking in a high-pitched voice'}, {'time': '21:40 PM', 'location': 'Bathroom', 'activity': 'Inflating balloons'}, {'time': '21:50 PM', 'location': 'Bathroom', 'activity': 'Polishing household items'}, {'time': '22:00 PM', 'location': 'Bathroom', 'activity': 'Rinsing a glass carefully'}, {'time': '22:10 PM', 'location': 'Living Room', 'activity': 'Ripping wippets'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '19:10 PM', 'location': 'Kitchen', 'activity': 'Opening a safe'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Inflating balloons'}, {'time': '19:30 PM', 'location': 'Dining Room', 'activity': 'Looking in drawers'}, {'time': '19:40 PM', 'location': 'Study', 'activity': 'Looking in drawers'}, {'time': '19:50 PM', 'location': 'Living Room', 'activity': 'Speaking in a high-pitched voice'}, {'time': '20:00 PM', 'location': 'Study', 'activity': 'Reading warning labels'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Taking her dog for a walk'}, {'time': '20:20 PM', 'location': 'Kitchen', 'activity': 'Speaking in a high-pitched voice'}, {'time': '20:30 PM', 'location': 'Pantry', 'activity': 'Looking in drawers'}, {'time': '20:40 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '20:50 PM', 'location': 'Dining Room', 'activity': 'Reading warning labels'}, {'time': '21:00 PM', 'location': 'Study', 'activity': 'Inflating balloons'}, {'time': '21:10 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Looking in drawers'}, {'time': '21:30 PM', 'location': 'Kitchen', 'activity': 'Inflating balloons'}, {'time': '21:40 PM', 'location': 'Pantry', 'activity': 'Looking in drawers'}, {'time': '21:50 PM', 'location': 'Kitchen', 'activity': 'Inspecting wine bottles'}, {'time': '22:00 PM', 'location': 'Pantry', 'activity': 'Talking about skeet shooting'}, {'time': '22:10 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Inflating balloons'}, {'time': '19:10 PM', 'location': 'Pantry', 'activity': 'Whittling a stick'}, {'time': '19:20 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '19:30 PM', 'location': 'Pantry', 'activity': 'Chatting with guests'}, {'time': '19:40 PM', 'location': 'Kitchen', 'activity': 'Inflating balloons'}, {'time': '19:50 PM', 'location': 'Pantry', 'activity': 'Bragging about their Birkin'}, {'time': '20:00 PM', 'location': 'Pantry', 'activity': 'Polishing household items'}, {'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '20:20 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '20:30 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '20:40 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '20:50 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Inflating balloons'}, {'time': '21:10 PM', 'location': 'Living Room', 'activity': 'Reading warning labels'}, {'time': '21:20 PM', 'location': 'Bathroom', 'activity': 'Opening a safe'}, {'time': '21:30 PM', 'location': 'Living Room', 'activity': 'Reading warning labels'}, {'time': '21:40 PM', 'location': 'Dining Room', 'activity': 'Observing guests from afar'}, {'time': '21:50 PM', 'location': 'Dining Room', 'activity': 'Looking in drawers'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Speaking in a high-pitched voice'}, {'time': '22:10 PM', 'location': 'Study', 'activity': 'Speaking in a high-pitched voice'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Pantry', 'activity': 'Looking in drawers'}, {'time': '19:10 PM', 'location': 'Kitchen', 'activity': 'Chatting with guests'}, {'time': '19:20 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '19:30 PM', 'location': 'Pantry', 'activity': 'Opening letters'}, {'time': '19:40 PM', 'location': 'Pantry', 'activity': 'Looking in drawers'}, {'time': '19:50 PM', 'location': 'Pantry', 'activity': 'Complaining about TSA going through their purse'}, {'time': '20:00 PM', 'location': 'Pantry', 'activity': 'Bragging about their Birkin'}, {'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '20:20 PM', 'location': 'Dining Room', 'activity': 'Speaking in a high-pitched voice'}, {'time': '20:30 PM', 'location': 'Study', 'activity': 'Bringing in the shopping'}, {'time': '20:40 PM', 'location': 'Study', 'activity': 'Reading warning labels'}, {'time': '20:50 PM', 'location': 'Living Room', 'activity': 'Reading warning labels'}, {'time': '21:00 PM', 'location': 'Bathroom', 'activity': 'Ripping wippets'}, {'time': '21:10 PM', 'location': 'Living Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:20 PM', 'location': 'Study', 'activity': 'Ripping wippets'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Reading warning labels'}, {'time': '21:40 PM', 'location': 'Dining Room', 'activity': 'Speaking in a high-pitched voice'}, {'time': '21:50 PM', 'location': 'Kitchen', 'activity': 'Observing guests from afar'}, {'time': '22:00 PM', 'location': 'Dining Room', 'activity': 'Reading warning labels'}, {'time': '22:10 PM', 'location': 'Kitchen', 'activity': 'Bragging about their Birkin'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Rinsing a glass carefully'}, {'time': '19:10 PM', 'location': 'Pantry', 'activity': 'Ripping wippets'}, {'time': '19:20 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '19:30 PM', 'location': 'Kitchen', 'activity': 'Raising a painting'}, {'time': '19:40 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '19:50 PM', 'location': 'Pantry', 'activity': 'Inflating balloons'}, {'time': '20:00 PM', 'location': 'Pantry', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Polishing household items'}, {'time': '20:20 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '20:30 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '20:40 PM', 'location': 'Kitchen', 'activity': 'Tampering with drinks'}, {'time': '20:50 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '21:00 PM', 'location': 'Pantry', 'activity': 'Inflating balloons'}, {'time': '21:10 PM', 'location': 'Kitchen', 'activity': 'Speaking in a high-pitched voice'}, {'time': '21:20 PM', 'location': 'Pantry', 'activity': 'Ripping wippets'}, {'time': '21:30 PM', 'location': 'Kitchen', 'activity': 'Polishing household items'}, {'time': '21:40 PM', 'location': 'Pantry', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:50 PM', 'location': 'Pantry', 'activity': 'Reading warning labels'}, {'time': '22:00 PM', 'location': 'Kitchen', 'activity': 'Returning to mingle with guests'}, {'time': '22:10 PM', 'location': 'Kitchen', 'activity': 'Speaking in a high-pitched voice'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Pantry', 'activity': 'Inspecting a family heirloom'}, {'time': '19:10 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Ripping wippets'}, {'time': '19:30 PM', 'location': 'Living Room', 'activity': 'Speaking in a high-pitched voice'}, {'time': '19:40 PM', 'location': 'Bathroom', 'activity': 'Looking in drawers'}, {'time': '19:50 PM', 'location': 'Bathroom', 'activity': 'Looking in drawers'}, {'time': '20:00 PM', 'location': 'Bathroom', 'activity': 'Inspecting wine bottles'}, {'time': '20:10 PM', 'location': 'Living Room', 'activity': 'Ripping wippets'}, {'time': '20:20 PM', 'location': 'Study', 'activity': 'Looking in drawers'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Inflating balloons'}, {'time': '20:40 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '20:50 PM', 'location': 'Pantry', 'activity': 'Reading warning labels'}, {'time': '21:00 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '21:10 PM', 'location': 'Pantry', 'activity': 'Speaking in a high-pitched voice'}, {'time': '21:20 PM', 'location': 'Kitchen', 'activity': 'Speaking in a high-pitched voice'}, {'time': '21:30 PM', 'location': 'Pantry', 'activity': 'Tampering with drinks'}, {'time': '21:40 PM', 'location': 'Pantry', 'activity': 'Speaking in a high-pitched voice'}, {'time': '21:50 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '22:00 PM', 'location': 'Pantry', 'activity': 'Reading warning labels'}, {'time': '22:10 PM', 'location': 'Kitchen', 'activity': 'Bragging about their Birkin'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Pantry', 'activity': 'Speaking in a high-pitched voice'}, {'time': '19:10 PM', 'location': 'Kitchen', 'activity': 'Inflating balloons'}, {'time': '19:20 PM', 'location': 'Pantry', 'activity': 'Ripping wippets'}, {'time': '19:30 PM', 'location': 'Pantry', 'activity': 'Serving drinks and chatting with guests'}, {'time': '19:40 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Inflating balloons'}, {'time': '20:00 PM', 'location': 'Living Room', 'activity': 'Looking in drawers'}, {'time': '20:10 PM', 'location': 'Study', 'activity': 'Taking her dog for a walk'}, {'time': '20:20 PM', 'location': 'Study', 'activity': 'Reading warning labels'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Speaking in a high-pitched voice'}, {'time': '20:40 PM', 'location': 'Living Room', 'activity': 'Ripping wippets'}, {'time': '20:50 PM', 'location': 'Study', 'activity': 'Reading warning labels'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Speaking in a high-pitched voice'}, {'time': '21:10 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '21:20 PM', 'location': 'Pantry', 'activity': 'Inflating balloons'}, {'time': '21:30 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '21:40 PM', 'location': 'Pantry', 'activity': 'Taking her dog for a walk'}, {'time': '21:50 PM', 'location': 'Kitchen', 'activity': 'Reading a novel quietly'}, {'time': '22:00 PM', 'location': 'Pantry', 'activity': 'Ripping wippets'}, {'time': '22:10 PM', 'location': 'Kitchen', 'activity': 'Whittling a stick'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Pantry', 'activity': 'Taking her dog for a walk'}, {'time': '19:10 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '19:20 PM', 'location': 'Pantry', 'activity': 'Ripping wippets'}, {'time': '19:30 PM', 'location': 'Kitchen', 'activity': 'Reorganizing books and materials'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Ripping wippets'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Inflating balloons'}, {'time': '20:00 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Inflating balloons'}, {'time': '20:20 PM', 'location': 'Pantry', 'activity': 'Opening a safe'}, {'time': '20:30 PM', 'location': 'Pantry', 'activity': 'Looking in drawers'}, {'time': '20:40 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '20:50 PM', 'location': 'Kitchen', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:00 PM', 'location': 'Pantry', 'activity': 'Looking in drawers'}, {'time': '21:10 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '21:20 PM', 'location': 'Pantry', 'activity': 'Inflating balloons'}, {'time': '21:30 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '21:40 PM', 'location': 'Pantry', 'activity': 'Speaking in a high-pitched voice'}, {'time': '21:50 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '22:00 PM', 'location': 'Dining Room', 'activity': 'Reading warning labels'}, {'time': '22:10 PM', 'location': 'Living Room', 'activity': 'Looking in drawers'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '19:10 PM', 'location': 'Dining Room', 'activity': 'Inflating balloons'}, {'time': '19:20 PM', 'location': 'Study', 'activity': 'Serving drinks and chatting with guests'}, {'time': '19:30 PM', 'location': 'Study', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:40 PM', 'location': 'Study', 'activity': 'Ripping wippets'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Returning to mingle with guests'}, {'time': '20:00 PM', 'location': 'Study', 'activity': 'Reading warning labels'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Reading warning labels'}, {'time': '20:20 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '20:30 PM', 'location': 'Pantry', 'activity': 'Opening a safe'}, {'time': '20:40 PM', 'location': 'Kitchen', 'activity': 'Bragging about their Birkin'}, {'time': '20:50 PM', 'location': 'Dining Room', 'activity': 'Inflating balloons'}, {'time': '21:00 PM', 'location': 'Kitchen', 'activity': 'Ripping wippets'}, {'time': '21:10 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '21:20 PM', 'location': 'Pantry', 'activity': 'Speaking in a high-pitched voice'}, {'time': '21:30 PM', 'location': 'Kitchen', 'activity': 'Speaking in a high-pitched voice'}, {'time': '21:40 PM', 'location': 'Pantry', 'activity': 'Reading warning labels'}, {'time': '21:50 PM', 'location': 'Kitchen', 'activity': 'Washing up after handling items'}, {'time': '22:00 PM', 'location': 'Dining Room', 'activity': 'Ripping wippets'}, {'time': '22:10 PM', 'location': 'Kitchen', 'activity': 'Inflating balloons'}]}], 'Mrs. Peacock': [{'suspect_statement': [{'time': '19:00 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:10 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Bringing in the shopping'}, {'time': '19:30 PM', 'location': 'Kitchen', 'activity': 'Raising a painting'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Bringing in the shopping'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Bringing in the shopping'}, {'time': '20:00 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '20:20 PM', 'location': 'Pantry', 'activity': 'Chatting with guests'}, {'time': '20:30 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '20:40 PM', 'location': 'Pantry', 'activity': 'Chatting with guests'}, {'time': '20:50 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Raising a painting'}, {'time': '21:10 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Bragging about their Birkin'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Washing up after handling items'}, {'time': '21:40 PM', 'location': 'Study', 'activity': 'Bragging about their Birkin'}, {'time': '21:50 PM', 'location': 'Study', 'activity': 'Retrieving items from storage'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Chatting with guests'}, {'time': '22:10 PM', 'location': 'Living Room', 'activity': 'Bringing in the shopping'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:10 PM', 'location': 'Kitchen', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Whittling a stick'}, {'time': '19:30 PM', 'location': 'Kitchen', 'activity': 'Polishing household items'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Bragging about their Birkin'}, {'time': '20:00 PM', 'location': 'Living Room', 'activity': 'Bragging about their Birkin'}, {'time': '20:10 PM', 'location': 'Bathroom', 'activity': 'Bringing in the shopping'}, {'time': '20:20 PM', 'location': 'Living Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Ripping wippets'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Opening letters'}, {'time': '20:50 PM', 'location': 'Dining Room', 'activity': 'Looking in drawers'}, {'time': '21:00 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '21:10 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '21:20 PM', 'location': 'Pantry', 'activity': 'Bragging about their Birkin'}, {'time': '21:30 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '21:40 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '21:50 PM', 'location': 'Kitchen', 'activity': 'Chatting with guests'}, {'time': '22:00 PM', 'location': 'Dining Room', 'activity': 'Returning to mingle with guests'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:10 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '19:20 PM', 'location': 'Kitchen', 'activity': 'Chatting with guests'}, {'time': '19:30 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:40 PM', 'location': 'Living Room', 'activity': 'Bragging about their Birkin'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Taking her dog for a walk'}, {'time': '20:00 PM', 'location': 'Kitchen', 'activity': 'Opening letters'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Bragging about their Birkin'}, {'time': '20:20 PM', 'location': 'Dining Room', 'activity': 'Inflating balloons'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Bragging about their Birkin'}, {'time': '20:50 PM', 'location': 'Study', 'activity': 'Chatting with guests'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Bragging about their Birkin'}, {'time': '21:20 PM', 'location': 'Kitchen', 'activity': 'Bragging about their Birkin'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '21:40 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '21:50 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '22:00 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '22:10 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:10 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:20 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '19:30 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '19:40 PM', 'location': 'Kitchen', 'activity': 'Chatting with guests'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '20:00 PM', 'location': 'Dining Room', 'activity': 'Bringing in the shopping'}, {'time': '20:10 PM', 'location': 'Study', 'activity': 'Complaining about TSA going through their purse'}, {'time': '20:20 PM', 'location': 'Living Room', 'activity': 'Chatting with guests'}, {'time': '20:30 PM', 'location': 'Living Room', 'activity': 'Chatting with guests'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '20:50 PM', 'location': 'Kitchen', 'activity': 'Serving drinks and chatting with guests'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Opening letters'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Bringing in the shopping'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Bragging about their Birkin'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '21:50 PM', 'location': 'Living Room', 'activity': 'Retrieving items from storage'}, {'time': '22:00 PM', 'location': 'Study', 'activity': 'Chatting with guests'}, {'time': '22:10 PM', 'location': 'Living Room', 'activity': 'Rinsing a glass carefully'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:10 PM', 'location': 'Kitchen', 'activity': 'Reading a novel quietly'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '19:30 PM', 'location': 'Kitchen', 'activity': 'Opening letters'}, {'time': '19:40 PM', 'location': 'Pantry', 'activity': 'Bragging about their Birkin'}, {'time': '19:50 PM', 'location': 'Kitchen', 'activity': 'Chatting with guests'}, {'time': '20:00 PM', 'location': 'Pantry', 'activity': 'Chatting with guests'}, {'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Bragging about their Birkin'}, {'time': '20:20 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '20:30 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Reorganizing books and materials'}, {'time': '20:50 PM', 'location': 'Dining Room', 'activity': 'Bragging about their Birkin'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Bragging about their Birkin'}, {'time': '21:30 PM', 'location': 'Living Room', 'activity': 'Opening a safe'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Bragging about their Birkin'}, {'time': '21:50 PM', 'location': 'Bathroom', 'activity': 'Retrieving items from storage'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Bragging about their Birkin'}, {'time': '22:10 PM', 'location': 'Study', 'activity': 'Bringing in the shopping'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Inspecting a family heirloom'}, {'time': '19:10 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Reorganizing books and materials'}, {'time': '19:30 PM', 'location': 'Living Room', 'activity': 'Retrieving items from storage'}, {'time': '19:40 PM', 'location': 'Bathroom', 'activity': 'Bringing in the shopping'}, {'time': '19:50 PM', 'location': 'Living Room', 'activity': 'Raising a painting'}, {'time': '20:00 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '20:20 PM', 'location': 'Kitchen', 'activity': 'Complaining about TSA going through their purse'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Bringing in the shopping'}, {'time': '20:40 PM', 'location': 'Living Room', 'activity': 'Bragging about their Birkin'}, {'time': '20:50 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '21:00 PM', 'location': 'Kitchen', 'activity': 'Raising a painting'}, {'time': '21:10 PM', 'location': 'Pantry', 'activity': 'Washing up after handling items'}, {'time': '21:20 PM', 'location': 'Kitchen', 'activity': 'Bragging about their Birkin'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Chatting with guests'}, {'time': '21:40 PM', 'location': 'Dining Room', 'activity': 'Talking about skeet shooting'}, {'time': '21:50 PM', 'location': 'Kitchen', 'activity': 'Reading a novel quietly'}, {'time': '22:00 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '22:10 PM', 'location': 'Kitchen', 'activity': 'Reorganizing books and materials'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Dining Room', 'activity': 'Chatting with guests'}, {'time': '19:10 PM', 'location': 'Kitchen', 'activity': 'Bragging about their Birkin'}, {'time': '19:20 PM', 'location': 'Pantry', 'activity': 'Chatting with guests'}, {'time': '19:30 PM', 'location': 'Pantry', 'activity': 'Ripping wippets'}, {'time': '19:40 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '20:00 PM', 'location': 'Dining Room', 'activity': 'Bragging about their Birkin'}, {'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Bragging about their Birkin'}, {'time': '20:20 PM', 'location': 'Dining Room', 'activity': 'Bragging about their Birkin'}, {'time': '20:30 PM', 'location': 'Living Room', 'activity': 'Chatting with guests'}, {'time': '20:40 PM', 'location': 'Study', 'activity': 'Complaining about TSA going through their purse'}, {'time': '20:50 PM', 'location': 'Dining Room', 'activity': 'Chatting with guests'}, {'time': '21:00 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Chatting with guests'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:30 PM', 'location': 'Kitchen', 'activity': 'Bragging about their Birkin'}, {'time': '21:40 PM', 'location': 'Kitchen', 'activity': 'Chatting with guests'}, {'time': '21:50 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '22:00 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '22:10 PM', 'location': 'Kitchen', 'activity': 'Bragging about their Birkin'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Chatting with guests'}, {'time': '19:10 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '19:20 PM', 'location': 'Kitchen', 'activity': 'Chatting with guests'}, {'time': '19:30 PM', 'location': 'Kitchen', 'activity': 'Chatting with guests'}, {'time': '19:40 PM', 'location': 'Kitchen', 'activity': 'Swapping drinks unnoticed'}, {'time': '19:50 PM', 'location': 'Kitchen', 'activity': 'Raising a painting'}, {'time': '20:00 PM', 'location': 'Kitchen', 'activity': 'Complaining about TSA going through their purse'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:20 PM', 'location': 'Kitchen', 'activity': 'Reading a novel quietly'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '20:50 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Bragging about their Birkin'}, {'time': '21:10 PM', 'location': 'Kitchen', 'activity': 'Bragging about their Birkin'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Bringing in the shopping'}, {'time': '21:40 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '21:50 PM', 'location': 'Pantry', 'activity': 'Bringing in the shopping'}, {'time': '22:00 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Inspecting a family heirloom'}, {'time': '19:10 PM', 'location': 'Pantry', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:20 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '19:30 PM', 'location': 'Kitchen', 'activity': 'Bragging about their Birkin'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Chatting with guests'}, {'time': '19:50 PM', 'location': 'Kitchen', 'activity': 'Chatting with guests'}, {'time': '20:00 PM', 'location': 'Kitchen', 'activity': 'Complaining about TSA going through their purse'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Tying decorative knots'}, {'time': '20:20 PM', 'location': 'Living Room', 'activity': 'Bringing in the shopping'}, {'time': '20:30 PM', 'location': 'Bathroom', 'activity': 'Chatting with guests'}, {'time': '20:40 PM', 'location': 'Living Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '20:50 PM', 'location': 'Bathroom', 'activity': 'Bragging about their Birkin'}, {'time': '21:00 PM', 'location': 'Bathroom', 'activity': 'Bragging about their Birkin'}, {'time': '21:10 PM', 'location': 'Living Room', 'activity': 'Chatting with guests'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:30 PM', 'location': 'Living Room', 'activity': 'Bragging about their Birkin'}, {'time': '21:40 PM', 'location': 'Bathroom', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:50 PM', 'location': 'Living Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '22:00 PM', 'location': 'Dining Room', 'activity': 'Opening letters'}, {'time': '22:10 PM', 'location': 'Kitchen', 'activity': 'Bragging about their Birkin'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Chatting with guests'}, {'time': '19:10 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '19:20 PM', 'location': 'Kitchen', 'activity': 'Chatting with guests'}, {'time': '19:30 PM', 'location': 'Kitchen', 'activity': 'Bragging about their Birkin'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Opening a safe'}, {'time': '20:00 PM', 'location': 'Dining Room', 'activity': 'Rinsing a glass carefully'}, {'time': '20:10 PM', 'location': 'Living Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '20:20 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '20:40 PM', 'location': 'Kitchen', 'activity': 'Bragging about their Birkin'}, {'time': '20:50 PM', 'location': 'Pantry', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:00 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Bringing in the shopping'}, {'time': '21:20 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Inspecting a family heirloom'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Bringing in the shopping'}, {'time': '21:50 PM', 'location': 'Dining Room', 'activity': 'Bringing in the shopping'}, {'time': '22:00 PM', 'location': 'Dining Room', 'activity': 'Bragging about their Birkin'}, {'time': '22:10 PM', 'location': 'Study', 'activity': 'Complaining about TSA going through their purse'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '19:10 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:30 PM', 'location': 'Living Room', 'activity': 'Retrieving items from storage'}, {'time': '19:40 PM', 'location': 'Living Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:50 PM', 'location': 'Study', 'activity': 'Complaining about TSA going through their purse'}, {'time': '20:00 PM', 'location': 'Dining Room', 'activity': 'Tying decorative knots'}, {'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Inspecting a family heirloom'}, {'time': '20:20 PM', 'location': 'Pantry', 'activity': 'Peeling an orange'}, {'time': '20:30 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Peeling an orange'}, {'time': '20:50 PM', 'location': 'Study', 'activity': 'Bringing in the shopping'}, {'time': '21:00 PM', 'location': 'Living Room', 'activity': 'Bragging about their Birkin'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:20 PM', 'location': 'Living Room', 'activity': 'Retrieving items from storage'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '21:40 PM', 'location': 'Kitchen', 'activity': 'Inspecting a family heirloom'}, {'time': '21:50 PM', 'location': 'Dining Room', 'activity': 'Bringing in the shopping'}, {'time': '22:00 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '22:10 PM', 'location': 'Study', 'activity': 'Retrieving items from storage'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Dining Room', 'activity': 'Chatting with guests'}, {'time': '19:10 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:20 PM', 'location': 'Study', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:30 PM', 'location': 'Study', 'activity': 'Talking about skeet shooting'}, {'time': '19:40 PM', 'location': 'Study', 'activity': 'Bringing in the shopping'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Bragging about their Birkin'}, {'time': '20:00 PM', 'location': 'Kitchen', 'activity': 'Chatting with guests'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '20:20 PM', 'location': 'Study', 'activity': 'Bragging about their Birkin'}, {'time': '20:30 PM', 'location': 'Living Room', 'activity': 'Ripping wippets'}, {'time': '20:40 PM', 'location': 'Study', 'activity': 'Chatting with guests'}, {'time': '20:50 PM', 'location': 'Study', 'activity': 'Bragging about their Birkin'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Bringing in the shopping'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:20 PM', 'location': 'Living Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Bringing in the shopping'}, {'time': '21:40 PM', 'location': 'Kitchen', 'activity': 'Inspecting wine bottles'}, {'time': '21:50 PM', 'location': 'Dining Room', 'activity': 'Whittling a stick'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Retrieving items from storage'}, {'time': '22:10 PM', 'location': 'Bathroom', 'activity': 'Retrieving items from storage'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Dining Room', 'activity': 'Chatting with guests'}, {'time': '19:10 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:20 PM', 'location': 'Kitchen', 'activity': 'Raising a painting'}, {'time': '19:30 PM', 'location': 'Pantry', 'activity': 'Opening a safe'}, {'time': '19:40 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '19:50 PM', 'location': 'Pantry', 'activity': 'Opening a safe'}, {'time': '20:00 PM', 'location': 'Kitchen', 'activity': 'Chatting with guests'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '20:20 PM', 'location': 'Living Room', 'activity': 'Chatting with guests'}, {'time': '20:30 PM', 'location': 'Study', 'activity': 'Polishing household items'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '20:50 PM', 'location': 'Study', 'activity': 'Retrieving items from storage'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Bragging about their Birkin'}, {'time': '21:10 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '21:20 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:40 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '21:50 PM', 'location': 'Dining Room', 'activity': 'Taking her dog for a walk'}, {'time': '22:00 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:10 PM', 'location': 'Pantry', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:20 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '19:30 PM', 'location': 'Kitchen', 'activity': 'Chatting with guests'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Bringing in the shopping'}, {'time': '19:50 PM', 'location': 'Kitchen', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:00 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '20:20 PM', 'location': 'Living Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '20:30 PM', 'location': 'Bathroom', 'activity': 'Retrieving items from storage'}, {'time': '20:40 PM', 'location': 'Living Room', 'activity': 'Bragging about their Birkin'}, {'time': '20:50 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:00 PM', 'location': 'Study', 'activity': 'Bringing in the shopping'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:20 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '21:30 PM', 'location': 'Pantry', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:40 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '21:50 PM', 'location': 'Pantry', 'activity': 'Chatting with guests'}, {'time': '22:00 PM', 'location': 'Kitchen', 'activity': 'Bragging about their Birkin'}, {'time': '22:10 PM', 'location': 'Pantry', 'activity': 'Bringing in the shopping'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '19:10 PM', 'location': 'Dining Room', 'activity': 'Peeling an orange'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '19:30 PM', 'location': 'Dining Room', 'activity': 'Raising a painting'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '19:50 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '20:00 PM', 'location': 'Pantry', 'activity': 'Bringing in the shopping'}, {'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Inflating balloons'}, {'time': '20:20 PM', 'location': 'Dining Room', 'activity': 'Whittling a stick'}, {'time': '20:30 PM', 'location': 'Kitchen', 'activity': 'Complaining about TSA going through their purse'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '20:50 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '21:00 PM', 'location': 'Pantry', 'activity': 'Chatting with guests'}, {'time': '21:10 PM', 'location': 'Kitchen', 'activity': 'Bragging about their Birkin'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Reading a novel quietly'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:40 PM', 'location': 'Dining Room', 'activity': 'Taking her dog for a walk'}, {'time': '21:50 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '22:00 PM', 'location': 'Pantry', 'activity': 'Bragging about their Birkin'}, {'time': '22:10 PM', 'location': 'Pantry', 'activity': 'Inspecting wine bottles'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Dining Room', 'activity': 'Observing guests from afar'}, {'time': '19:10 PM', 'location': 'Dining Room', 'activity': 'Bragging about their Birkin'}, {'time': '19:20 PM', 'location': 'Study', 'activity': 'Retrieving items from storage'}, {'time': '19:30 PM', 'location': 'Study', 'activity': 'Bringing in the shopping'}, {'time': '19:40 PM', 'location': 'Living Room', 'activity': 'Chatting with guests'}, {'time': '19:50 PM', 'location': 'Study', 'activity': 'Retrieving items from storage'}, {'time': '20:00 PM', 'location': 'Dining Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '20:20 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '20:40 PM', 'location': 'Kitchen', 'activity': 'Opening a safe'}, {'time': '20:50 PM', 'location': 'Pantry', 'activity': 'Rinsing a glass carefully'}, {'time': '21:00 PM', 'location': 'Kitchen', 'activity': 'Polishing household items'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Bringing in the shopping'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Bringing in the shopping'}, {'time': '21:40 PM', 'location': 'Kitchen', 'activity': 'Inflating balloons'}, {'time': '21:50 PM', 'location': 'Dining Room', 'activity': 'Chatting with guests'}, {'time': '22:00 PM', 'location': 'Kitchen', 'activity': 'Polishing household items'}, {'time': '22:10 PM', 'location': 'Kitchen', 'activity': 'Chatting with guests'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Chatting with guests'}, {'time': '19:10 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '19:20 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '19:30 PM', 'location': 'Pantry', 'activity': 'Retrieving items from storage'}, {'time': '19:40 PM', 'location': 'Pantry', 'activity': 'Bringing in the shopping'}, {'time': '19:50 PM', 'location': 'Kitchen', 'activity': 'Taking her dog for a walk'}, {'time': '20:00 PM', 'location': 'Dining Room', 'activity': 'Bringing in the shopping'}, {'time': '20:10 PM', 'location': 'Living Room', 'activity': 'Bragging about their Birkin'}, {'time': '20:20 PM', 'location': 'Bathroom', 'activity': 'Retrieving items from storage'}, {'time': '20:30 PM', 'location': 'Bathroom', 'activity': 'Chatting with guests'}, {'time': '20:40 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '20:50 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '21:00 PM', 'location': 'Study', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:10 PM', 'location': 'Study', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:20 PM', 'location': 'Study', 'activity': 'Chatting with guests'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Chatting with guests'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Retrieving items from storage'}, {'time': '21:50 PM', 'location': 'Bathroom', 'activity': 'Chatting with guests'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Retrieving items from storage'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Bragging about their Birkin'}, {'time': '19:10 PM', 'location': 'Pantry', 'activity': 'Retrieving items from storage'}, {'time': '19:20 PM', 'location': 'Kitchen', 'activity': 'Taking her dog for a walk'}, {'time': '19:30 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Washing up after handling items'}, {'time': '20:00 PM', 'location': 'Living Room', 'activity': 'Bringing in the shopping'}, {'time': '20:10 PM', 'location': 'Study', 'activity': 'Bringing in the shopping'}, {'time': '20:20 PM', 'location': 'Study', 'activity': 'Bringing in the shopping'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Chatting with guests'}, {'time': '20:40 PM', 'location': 'Study', 'activity': 'Chatting with guests'}, {'time': '20:50 PM', 'location': 'Dining Room', 'activity': 'Chatting with guests'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Bragging about their Birkin'}, {'time': '21:20 PM', 'location': 'Study', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:30 PM', 'location': 'Living Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:40 PM', 'location': 'Study', 'activity': 'Chatting with guests'}, {'time': '21:50 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '22:00 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '19:10 PM', 'location': 'Dining Room', 'activity': 'Reading warning labels'}, {'time': '19:20 PM', 'location': 'Kitchen', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:30 PM', 'location': 'Kitchen', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:40 PM', 'location': 'Pantry', 'activity': 'Bragging about their Birkin'}, {'time': '19:50 PM', 'location': 'Kitchen', 'activity': 'Complaining about TSA going through their purse'}, {'time': '20:00 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}, {'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Speaking in a high-pitched voice'}, {'time': '20:20 PM', 'location': 'Kitchen', 'activity': 'Peeling an orange'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Chatting with guests'}, {'time': '20:40 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '20:50 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Chatting with guests'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Speaking in a high-pitched voice'}, {'time': '21:20 PM', 'location': 'Kitchen', 'activity': 'Returning to mingle with guests'}, {'time': '21:30 PM', 'location': 'Kitchen', 'activity': 'Bragging about their Birkin'}, {'time': '21:40 PM', 'location': 'Dining Room', 'activity': 'Bringing in the shopping'}, {'time': '21:50 PM', 'location': 'Dining Room', 'activity': 'Bringing in the shopping'}, {'time': '22:00 PM', 'location': 'Study', 'activity': 'Chatting with guests'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Peeling an orange'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Kitchen', 'activity': 'Chatting with guests'}, {'time': '19:10 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Chatting with guests'}, {'time': '19:30 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '19:40 PM', 'location': 'Kitchen', 'activity': 'Chatting with guests'}, {'time': '19:50 PM', 'location': 'Kitchen', 'activity': 'Peeling an orange'}, {'time': '20:00 PM', 'location': 'Dining Room', 'activity': 'Reorganizing books and materials'}, {'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '20:20 PM', 'location': 'Pantry', 'activity': 'Chatting with guests'}, {'time': '20:30 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '20:50 PM', 'location': 'Kitchen', 'activity': 'Retrieving items from storage'}, {'time': '21:00 PM', 'location': 'Pantry', 'activity': 'Bragging about their Birkin'}, {'time': '21:10 PM', 'location': 'Kitchen', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Raising a painting'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Opening letters'}, {'time': '21:40 PM', 'location': 'Kitchen', 'activity': 'Chatting with guests'}, {'time': '21:50 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '22:00 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '22:10 PM', 'location': 'Kitchen', 'activity': 'Chatting with guests'}]}], 'Professor Plum': [{'suspect_statement': [{'time': '19:00 PM', 'location': 'Bathroom', 'activity': 'Peeling an orange'}, {'time': '19:10 PM', 'location': 'Living Room', 'activity': 'Whittling a stick'}, {'time': '19:20 PM', 'location': 'Living Room', 'activity': 'Returning to mingle with guests'}, {'time': '19:30 PM', 'location': 'Bathroom', 'activity': 'Inflating balloons'}, {'time': '19:40 PM', 'location': 'Bathroom', 'activity': 'Returning to mingle with guests'}, {'time': '19:50 PM', 'location': 'Living Room', 'activity': 'Peeling an orange'}, {'time': '20:00 PM', 'location': 'Bathroom', 'activity': 'Taking her dog for a walk'}, {'time': '20:10 PM', 'location': 'Bathroom', 'activity': 'Reading a novel quietly'}, {'time': '20:20 PM', 'location': 'Bathroom', 'activity': 'Whittling a stick'}, {'time': '20:30 PM', 'location': 'Bathroom', 'activity': 'Peeling an orange'}, {'time': '20:40 PM', 'location': 'Bathroom', 'activity': 'Opening letters'}, {'time': '20:50 PM', 'location': 'Bathroom', 'activity': 'Returning to mingle with guests'}, {'time': '21:00 PM', 'location': 'Living Room', 'activity': 'Returning to mingle with guests'}, {'time': '21:10 PM', 'location': 'Bathroom', 'activity': 'Returning to mingle with guests'}, {'time': '21:20 PM', 'location': 'Living Room', 'activity': 'Opening letters'}, {'time': '21:30 PM', 'location': 'Bathroom', 'activity': 'Returning to mingle with guests'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Tying decorative knots'}, {'time': '21:50 PM', 'location': 'Bathroom', 'activity': 'Opening letters'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Reading a novel quietly'}, {'time': '22:10 PM', 'location': 'Study', 'activity': 'Peeling an orange'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '19:10 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Tying decorative knots'}, {'time': '19:30 PM', 'location': 'Study', 'activity': 'Polishing household items'}, {'time': '19:40 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '19:50 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '20:00 PM', 'location': 'Study', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Peeling an orange'}, {'time': '20:20 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}, {'time': '20:30 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '20:40 PM', 'location': 'Living Room', 'activity': 'Reading a novel quietly'}, {'time': '20:50 PM', 'location': 'Dining Room', 'activity': 'Retrieving items from storage'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Opening letters'}, {'time': '21:10 PM', 'location': 'Study', 'activity': 'Serving drinks and chatting with guests'}, {'time': '21:20 PM', 'location': 'Living Room', 'activity': 'Opening letters'}, {'time': '21:30 PM', 'location': 'Bathroom', 'activity': 'Reading a novel quietly'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Returning to mingle with guests'}, {'time': '21:50 PM', 'location': 'Dining Room', 'activity': 'Opening letters'}, {'time': '22:00 PM', 'location': 'Study', 'activity': 'Raising a painting'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Whittling a stick'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Study', 'activity': 'Whittling a stick'}, {'time': '19:10 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '19:20 PM', 'location': 'Study', 'activity': 'Inspecting wine bottles'}, {'time': '19:30 PM', 'location': 'Living Room', 'activity': 'Peeling an orange'}, {'time': '19:40 PM', 'location': 'Study', 'activity': 'Taking her dog for a walk'}, {'time': '19:50 PM', 'location': 'Living Room', 'activity': 'Opening letters'}, {'time': '20:00 PM', 'location': 'Living Room', 'activity': 'Peeling an orange'}, {'time': '20:10 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '20:20 PM', 'location': 'Living Room', 'activity': 'Peeling an orange'}, {'time': '20:30 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '20:40 PM', 'location': 'Study', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:50 PM', 'location': 'Living Room', 'activity': 'Peeling an orange'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Opening letters'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Reading a novel quietly'}, {'time': '21:20 PM', 'location': 'Study', 'activity': 'Speaking in a high-pitched voice'}, {'time': '21:30 PM', 'location': 'Study', 'activity': 'Inspecting wine bottles'}, {'time': '21:40 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '21:50 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '22:00 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '22:10 PM', 'location': 'Study', 'activity': 'Tying decorative knots'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '19:10 PM', 'location': 'Dining Room', 'activity': 'Whittling a stick'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Opening letters'}, {'time': '19:30 PM', 'location': 'Kitchen', 'activity': 'Whittling a stick'}, {'time': '19:40 PM', 'location': 'Pantry', 'activity': 'Opening letters'}, {'time': '19:50 PM', 'location': 'Kitchen', 'activity': 'Observing guests from afar'}, {'time': '20:00 PM', 'location': 'Pantry', 'activity': 'Whittling a stick'}, {'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Returning to mingle with guests'}, {'time': '20:20 PM', 'location': 'Pantry', 'activity': 'Whittling a stick'}, {'time': '20:30 PM', 'location': 'Kitchen', 'activity': 'Talking about skeet shooting'}, {'time': '20:40 PM', 'location': 'Pantry', 'activity': 'Peeling an orange'}, {'time': '20:50 PM', 'location': 'Kitchen', 'activity': 'Inflating balloons'}, {'time': '21:00 PM', 'location': 'Kitchen', 'activity': 'Peeling an orange'}, {'time': '21:10 PM', 'location': 'Pantry', 'activity': 'Retrieving items from storage'}, {'time': '21:20 PM', 'location': 'Pantry', 'activity': 'Observing guests from afar'}, {'time': '21:30 PM', 'location': 'Kitchen', 'activity': 'Whittling a stick'}, {'time': '21:40 PM', 'location': 'Dining Room', 'activity': 'Whittling a stick'}, {'time': '21:50 PM', 'location': 'Kitchen', 'activity': 'Reading a novel quietly'}, {'time': '22:00 PM', 'location': 'Pantry', 'activity': 'Whittling a stick'}, {'time': '22:10 PM', 'location': 'Kitchen', 'activity': 'Talking about skeet shooting'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '19:10 PM', 'location': 'Dining Room', 'activity': 'Inspecting a family heirloom'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Reading a novel quietly'}, {'time': '19:30 PM', 'location': 'Dining Room', 'activity': 'Whittling a stick'}, {'time': '19:40 PM', 'location': 'Kitchen', 'activity': 'Whittling a stick'}, {'time': '19:50 PM', 'location': 'Kitchen', 'activity': 'Opening letters'}, {'time': '20:00 PM', 'location': 'Pantry', 'activity': 'Returning to mingle with guests'}, {'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Whittling a stick'}, {'time': '20:20 PM', 'location': 'Dining Room', 'activity': 'Whittling a stick'}, {'time': '20:30 PM', 'location': 'Kitchen', 'activity': 'Peeling an orange'}, {'time': '20:40 PM', 'location': 'Pantry', 'activity': 'Tampering with drinks'}, {'time': '20:50 PM', 'location': 'Kitchen', 'activity': 'Returning to mingle with guests'}, {'time': '21:00 PM', 'location': 'Pantry', 'activity': 'Reading warning labels'}, {'time': '21:10 PM', 'location': 'Kitchen', 'activity': 'Peeling an orange'}, {'time': '21:20 PM', 'location': 'Kitchen', 'activity': 'Reorganizing books and materials'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Opening letters'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Bringing in the shopping'}, {'time': '21:50 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '22:00 PM', 'location': 'Study', 'activity': 'Whittling a stick'}, {'time': '22:10 PM', 'location': 'Study', 'activity': 'Inflating balloons'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '19:10 PM', 'location': 'Dining Room', 'activity': 'Raising a painting'}, {'time': '19:20 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '19:30 PM', 'location': 'Dining Room', 'activity': 'Whittling a stick'}, {'time': '19:40 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '19:50 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '20:00 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '20:10 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '20:20 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '20:30 PM', 'location': 'Living Room', 'activity': 'Opening letters'}, {'time': '20:40 PM', 'location': 'Study', 'activity': 'Whittling a stick'}, {'time': '20:50 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '21:00 PM', 'location': 'Study', 'activity': 'Washing up after handling items'}, {'time': '21:10 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Peeling an orange'}, {'time': '21:30 PM', 'location': 'Living Room', 'activity': 'Washing up after handling items'}, {'time': '21:40 PM', 'location': 'Study', 'activity': 'Retrieving items from storage'}, {'time': '21:50 PM', 'location': 'Dining Room', 'activity': 'Peeling an orange'}, {'time': '22:00 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '22:10 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Bathroom', 'activity': 'Peeling an orange'}, {'time': '19:10 PM', 'location': 'Bathroom', 'activity': 'Reorganizing books and materials'}, {'time': '19:20 PM', 'location': 'Living Room', 'activity': 'Returning to mingle with guests'}, {'time': '19:30 PM', 'location': 'Living Room', 'activity': 'Whittling a stick'}, {'time': '19:40 PM', 'location': 'Study', 'activity': 'Whittling a stick'}, {'time': '19:50 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '20:00 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '20:10 PM', 'location': 'Study', 'activity': 'Opening a safe'}, {'time': '20:20 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}, {'time': '20:30 PM', 'location': 'Study', 'activity': 'Opening a safe'}, {'time': '20:40 PM', 'location': 'Living Room', 'activity': 'Returning to mingle with guests'}, {'time': '20:50 PM', 'location': 'Dining Room', 'activity': 'Returning to mingle with guests'}, {'time': '21:00 PM', 'location': 'Study', 'activity': 'Whittling a stick'}, {'time': '21:10 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '21:20 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '21:30 PM', 'location': 'Living Room', 'activity': 'Whittling a stick'}, {'time': '21:40 PM', 'location': 'Bathroom', 'activity': 'Peeling an orange'}, {'time': '21:50 PM', 'location': 'Bathroom', 'activity': 'Whittling a stick'}, {'time': '22:00 PM', 'location': 'Bathroom', 'activity': 'Returning to mingle with guests'}, {'time': '22:10 PM', 'location': 'Bathroom', 'activity': 'Inspecting wine bottles'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '19:10 PM', 'location': 'Living Room', 'activity': 'Returning to mingle with guests'}, {'time': '19:20 PM', 'location': 'Bathroom', 'activity': 'Opening letters'}, {'time': '19:30 PM', 'location': 'Bathroom', 'activity': 'Peeling an orange'}, {'time': '19:40 PM', 'location': 'Bathroom', 'activity': 'Peeling an orange'}, {'time': '19:50 PM', 'location': 'Bathroom', 'activity': 'Whittling a stick'}, {'time': '20:00 PM', 'location': 'Living Room', 'activity': 'Rinsing a glass carefully'}, {'time': '20:10 PM', 'location': 'Bathroom', 'activity': 'Looking in drawers'}, {'time': '20:20 PM', 'location': 'Living Room', 'activity': 'Whittling a stick'}, {'time': '20:30 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Peeling an orange'}, {'time': '20:50 PM', 'location': 'Kitchen', 'activity': 'Whittling a stick'}, {'time': '21:00 PM', 'location': 'Kitchen', 'activity': 'Reading a novel quietly'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Peeling an orange'}, {'time': '21:20 PM', 'location': 'Living Room', 'activity': 'Whittling a stick'}, {'time': '21:30 PM', 'location': 'Bathroom', 'activity': 'Peeling an orange'}, {'time': '21:40 PM', 'location': 'Bathroom', 'activity': 'Ripping wippets'}, {'time': '21:50 PM', 'location': 'Living Room', 'activity': 'Returning to mingle with guests'}, {'time': '22:00 PM', 'location': 'Bathroom', 'activity': 'Returning to mingle with guests'}, {'time': '22:10 PM', 'location': 'Living Room', 'activity': 'Whittling a stick'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '19:10 PM', 'location': 'Living Room', 'activity': 'Reading a novel quietly'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Returning to mingle with guests'}, {'time': '19:30 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '19:40 PM', 'location': 'Study', 'activity': 'Tying decorative knots'}, {'time': '19:50 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '20:00 PM', 'location': 'Study', 'activity': 'Inspecting wine bottles'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Peeling an orange'}, {'time': '20:20 PM', 'location': 'Study', 'activity': 'Retrieving items from storage'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Whittling a stick'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Opening letters'}, {'time': '20:50 PM', 'location': 'Kitchen', 'activity': 'Returning to mingle with guests'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Whittling a stick'}, {'time': '21:10 PM', 'location': 'Living Room', 'activity': 'Whittling a stick'}, {'time': '21:20 PM', 'location': 'Bathroom', 'activity': 'Whittling a stick'}, {'time': '21:30 PM', 'location': 'Living Room', 'activity': 'Rinsing a glass carefully'}, {'time': '21:40 PM', 'location': 'Bathroom', 'activity': 'Opening letters'}, {'time': '21:50 PM', 'location': 'Bathroom', 'activity': 'Tampering with drinks'}, {'time': '22:00 PM', 'location': 'Bathroom', 'activity': 'Swapping drinks unnoticed'}, {'time': '22:10 PM', 'location': 'Living Room', 'activity': 'Peeling an orange'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Bathroom', 'activity': 'Whittling a stick'}, {'time': '19:10 PM', 'location': 'Bathroom', 'activity': 'Whittling a stick'}, {'time': '19:20 PM', 'location': 'Bathroom', 'activity': 'Retrieving items from storage'}, {'time': '19:30 PM', 'location': 'Living Room', 'activity': 'Reorganizing books and materials'}, {'time': '19:40 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '19:50 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '20:00 PM', 'location': 'Study', 'activity': 'Whittling a stick'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}, {'time': '20:20 PM', 'location': 'Kitchen', 'activity': 'Reading a novel quietly'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Reading a novel quietly'}, {'time': '20:40 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '20:50 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '21:00 PM', 'location': 'Study', 'activity': 'Reading warning labels'}, {'time': '21:10 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '21:20 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '21:30 PM', 'location': 'Study', 'activity': 'Ripping wippets'}, {'time': '21:40 PM', 'location': 'Study', 'activity': 'Whittling a stick'}, {'time': '21:50 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '22:00 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Reading warning labels'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Study', 'activity': 'Inspecting wine bottles'}, {'time': '19:10 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Peeling an orange'}, {'time': '19:30 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '19:40 PM', 'location': 'Study', 'activity': 'Tying decorative knots'}, {'time': '19:50 PM', 'location': 'Study', 'activity': 'Washing up after handling items'}, {'time': '20:00 PM', 'location': 'Living Room', 'activity': 'Peeling an orange'}, {'time': '20:10 PM', 'location': 'Study', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:20 PM', 'location': 'Study', 'activity': 'Bragging about their Birkin'}, {'time': '20:30 PM', 'location': 'Living Room', 'activity': 'Peeling an orange'}, {'time': '20:40 PM', 'location': 'Study', 'activity': 'Whittling a stick'}, {'time': '20:50 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '21:00 PM', 'location': 'Living Room', 'activity': 'Opening letters'}, {'time': '21:10 PM', 'location': 'Bathroom', 'activity': 'Peeling an orange'}, {'time': '21:20 PM', 'location': 'Bathroom', 'activity': 'Peeling an orange'}, {'time': '21:30 PM', 'location': 'Living Room', 'activity': 'Peeling an orange'}, {'time': '21:40 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '21:50 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '22:00 PM', 'location': 'Study', 'activity': 'Talking about skeet shooting'}, {'time': '22:10 PM', 'location': 'Study', 'activity': 'Ripping wippets'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '19:10 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '19:20 PM', 'location': 'Study', 'activity': 'Rinsing a glass carefully'}, {'time': '19:30 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '19:40 PM', 'location': 'Study', 'activity': 'Observing guests from afar'}, {'time': '19:50 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '20:00 PM', 'location': 'Study', 'activity': 'Whittling a stick'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Tampering with drinks'}, {'time': '20:20 PM', 'location': 'Study', 'activity': 'Inspecting a family heirloom'}, {'time': '20:30 PM', 'location': 'Study', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '20:50 PM', 'location': 'Study', 'activity': 'Tampering with drinks'}, {'time': '21:00 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Peeling an orange'}, {'time': '21:20 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Returning to mingle with guests'}, {'time': '21:40 PM', 'location': 'Dining Room', 'activity': 'Returning to mingle with guests'}, {'time': '21:50 PM', 'location': 'Dining Room', 'activity': 'Whittling a stick'}, {'time': '22:00 PM', 'location': 'Kitchen', 'activity': 'Returning to mingle with guests'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Opening a safe'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Bathroom', 'activity': 'Returning to mingle with guests'}, {'time': '19:10 PM', 'location': 'Living Room', 'activity': 'Peeling an orange'}, {'time': '19:20 PM', 'location': 'Bathroom', 'activity': 'Peeling an orange'}, {'time': '19:30 PM', 'location': 'Living Room', 'activity': 'Talking about skeet shooting'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Returning to mingle with guests'}, {'time': '19:50 PM', 'location': 'Kitchen', 'activity': 'Whittling a stick'}, {'time': '20:00 PM', 'location': 'Kitchen', 'activity': 'Reading a novel quietly'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Bragging about their Birkin'}, {'time': '20:20 PM', 'location': 'Kitchen', 'activity': 'Whittling a stick'}, {'time': '20:30 PM', 'location': 'Dining Room', 'activity': 'Looking in drawers'}, {'time': '20:40 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '20:50 PM', 'location': 'Living Room', 'activity': 'Inflating balloons'}, {'time': '21:00 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '21:10 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '21:20 PM', 'location': 'Study', 'activity': 'Whittling a stick'}, {'time': '21:30 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '21:40 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '21:50 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '22:00 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Whittling a stick'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Bathroom', 'activity': 'Opening letters'}, {'time': '19:10 PM', 'location': 'Living Room', 'activity': 'Reading a novel quietly'}, {'time': '19:20 PM', 'location': 'Bathroom', 'activity': 'Tying decorative knots'}, {'time': '19:30 PM', 'location': 'Living Room', 'activity': 'Taking her dog for a walk'}, {'time': '19:40 PM', 'location': 'Bathroom', 'activity': 'Whittling a stick'}, {'time': '19:50 PM', 'location': 'Bathroom', 'activity': 'Peeling an orange'}, {'time': '20:00 PM', 'location': 'Living Room', 'activity': 'Peeling an orange'}, {'time': '20:10 PM', 'location': 'Study', 'activity': 'Whittling a stick'}, {'time': '20:20 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '20:30 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '20:40 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '20:50 PM', 'location': 'Living Room', 'activity': 'Opening letters'}, {'time': '21:00 PM', 'location': 'Bathroom', 'activity': 'Returning to mingle with guests'}, {'time': '21:10 PM', 'location': 'Living Room', 'activity': 'Whittling a stick'}, {'time': '21:20 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Inflating balloons'}, {'time': '21:40 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '21:50 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '22:00 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '22:10 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Bathroom', 'activity': 'Tying decorative knots'}, {'time': '19:10 PM', 'location': 'Living Room', 'activity': 'Speaking in a high-pitched voice'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Taking her dog for a walk'}, {'time': '19:30 PM', 'location': 'Study', 'activity': 'Whittling a stick'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Reading a novel quietly'}, {'time': '19:50 PM', 'location': 'Living Room', 'activity': 'Returning to mingle with guests'}, {'time': '20:00 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '20:10 PM', 'location': 'Study', 'activity': 'Whittling a stick'}, {'time': '20:20 PM', 'location': 'Living Room', 'activity': 'Reading a novel quietly'}, {'time': '20:30 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '20:40 PM', 'location': 'Living Room', 'activity': 'Whittling a stick'}, {'time': '20:50 PM', 'location': 'Bathroom', 'activity': 'Whittling a stick'}, {'time': '21:00 PM', 'location': 'Bathroom', 'activity': 'Peeling an orange'}, {'time': '21:10 PM', 'location': 'Living Room', 'activity': 'Opening letters'}, {'time': '21:20 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '21:30 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Reading a novel quietly'}, {'time': '21:50 PM', 'location': 'Bathroom', 'activity': 'Returning to mingle with guests'}, {'time': '22:00 PM', 'location': 'Bathroom', 'activity': 'Whittling a stick'}, {'time': '22:10 PM', 'location': 'Bathroom', 'activity': 'Returning to mingle with guests'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '19:10 PM', 'location': 'Dining Room', 'activity': 'Whittling a stick'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Opening letters'}, {'time': '19:30 PM', 'location': 'Living Room', 'activity': 'Inspecting a family heirloom'}, {'time': '19:40 PM', 'location': 'Study', 'activity': 'Chatting with guests'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Observing guests from afar'}, {'time': '20:00 PM', 'location': 'Study', 'activity': 'Whittling a stick'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Returning to mingle with guests'}, {'time': '20:20 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '20:30 PM', 'location': 'Study', 'activity': 'Tying decorative knots'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Opening letters'}, {'time': '20:50 PM', 'location': 'Dining Room', 'activity': 'Peeling an orange'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Reading a novel quietly'}, {'time': '21:10 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '21:20 PM', 'location': 'Living Room', 'activity': 'Whittling a stick'}, {'time': '21:30 PM', 'location': 'Bathroom', 'activity': 'Returning to mingle with guests'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Reading a novel quietly'}, {'time': '21:50 PM', 'location': 'Bathroom', 'activity': 'Reading a novel quietly'}, {'time': '22:00 PM', 'location': 'Bathroom', 'activity': 'Peeling an orange'}, {'time': '22:10 PM', 'location': 'Bathroom', 'activity': 'Complaining about TSA going through their purse'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '19:10 PM', 'location': 'Study', 'activity': 'Taking her dog for a walk'}, {'time': '19:20 PM', 'location': 'Living Room', 'activity': 'Returning to mingle with guests'}, {'time': '19:30 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '19:40 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '19:50 PM', 'location': 'Study', 'activity': 'Whittling a stick'}, {'time': '20:00 PM', 'location': 'Study', 'activity': 'Ripping wippets'}, {'time': '20:10 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '20:20 PM', 'location': 'Living Room', 'activity': 'Returning to mingle with guests'}, {'time': '20:30 PM', 'location': 'Study', 'activity': 'Whittling a stick'}, {'time': '20:40 PM', 'location': 'Study', 'activity': 'Observing guests from afar'}, {'time': '20:50 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '21:00 PM', 'location': 'Study', 'activity': 'Observing guests from afar'}, {'time': '21:10 PM', 'location': 'Study', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Peeling an orange'}, {'time': '21:30 PM', 'location': 'Dining Room', 'activity': 'Looking in drawers'}, {'time': '21:40 PM', 'location': 'Kitchen', 'activity': 'Taking her dog for a walk'}, {'time': '21:50 PM', 'location': 'Pantry', 'activity': 'Whittling a stick'}, {'time': '22:00 PM', 'location': 'Kitchen', 'activity': 'Whittling a stick'}, {'time': '22:10 PM', 'location': 'Pantry', 'activity': 'Peeling an orange'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Bathroom', 'activity': 'Opening letters'}, {'time': '19:10 PM', 'location': 'Living Room', 'activity': 'Returning to mingle with guests'}, {'time': '19:20 PM', 'location': 'Bathroom', 'activity': 'Returning to mingle with guests'}, {'time': '19:30 PM', 'location': 'Living Room', 'activity': 'Whittling a stick'}, {'time': '19:40 PM', 'location': 'Living Room', 'activity': 'Reading a novel quietly'}, {'time': '19:50 PM', 'location': 'Bathroom', 'activity': 'Peeling an orange'}, {'time': '20:00 PM', 'location': 'Bathroom', 'activity': 'Opening letters'}, {'time': '20:10 PM', 'location': 'Bathroom', 'activity': 'Reading a novel quietly'}, {'time': '20:20 PM', 'location': 'Living Room', 'activity': 'Opening letters'}, {'time': '20:30 PM', 'location': 'Living Room', 'activity': 'Whittling a stick'}, {'time': '20:40 PM', 'location': 'Study', 'activity': 'Whittling a stick'}, {'time': '20:50 PM', 'location': 'Study', 'activity': 'Whittling a stick'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Opening letters'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Opening letters'}, {'time': '21:20 PM', 'location': 'Study', 'activity': 'Whittling a stick'}, {'time': '21:30 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '21:40 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '21:50 PM', 'location': 'Living Room', 'activity': 'Whittling a stick'}, {'time': '22:00 PM', 'location': 'Study', 'activity': 'Whittling a stick'}, {'time': '22:10 PM', 'location': 'Study', 'activity': 'Peeling an orange'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '19:10 PM', 'location': 'Living Room', 'activity': 'Returning to mingle with guests'}, {'time': '19:20 PM', 'location': 'Study', 'activity': 'Tampering with drinks'}, {'time': '19:30 PM', 'location': 'Dining Room', 'activity': 'Returning to mingle with guests'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Whittling a stick'}, {'time': '19:50 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '20:00 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '20:10 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '20:20 PM', 'location': 'Study', 'activity': 'Whittling a stick'}, {'time': '20:30 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '20:40 PM', 'location': 'Study', 'activity': 'Looking in drawers'}, {'time': '20:50 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '21:00 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '21:10 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '21:20 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '21:30 PM', 'location': 'Study', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:40 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '21:50 PM', 'location': 'Dining Room', 'activity': 'Peeling an orange'}, {'time': '22:00 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '22:10 PM', 'location': 'Living Room', 'activity': 'Whittling a stick'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Bathroom', 'activity': 'Opening letters'}, {'time': '19:10 PM', 'location': 'Living Room', 'activity': 'Reading a novel quietly'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Returning to mingle with guests'}, {'time': '19:30 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '19:40 PM', 'location': 'Study', 'activity': 'Washing up after handling items'}, {'time': '19:50 PM', 'location': 'Study', 'activity': 'Bringing in the shopping'}, {'time': '20:00 PM', 'location': 'Living Room', 'activity': 'Reading a novel quietly'}, {'time': '20:10 PM', 'location': 'Study', 'activity': 'Whittling a stick'}, {'time': '20:20 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '20:30 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '20:40 PM', 'location': 'Study', 'activity': 'Whittling a stick'}, {'time': '20:50 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '21:00 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '21:10 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '21:20 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '21:30 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Inflating balloons'}, {'time': '21:50 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Reading a novel quietly'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Chatting with guests'}]}], 'Miss Scarlet': [{'suspect_statement': [{'time': '19:00 PM', 'location': 'Living Room', 'activity': 'Raising a painting'}, {'time': '19:10 PM', 'location': 'Living Room', 'activity': 'Taking her dog for a walk'}, {'time': '19:20 PM', 'location': 'Study', 'activity': 'Raising a painting'}, {'time': '19:30 PM', 'location': 'Dining Room', 'activity': 'Taking her dog for a walk'}, {'time': '19:40 PM', 'location': 'Living Room', 'activity': 'Reorganizing books and materials'}, {'time': '19:50 PM', 'location': 'Living Room', 'activity': 'Washing up after handling items'}, {'time': '20:00 PM', 'location': 'Living Room', 'activity': 'Reorganizing books and materials'}, {'time': '20:10 PM', 'location': 'Bathroom', 'activity': 'Speaking in a high-pitched voice'}, {'time': '20:20 PM', 'location': 'Bathroom', 'activity': 'Reorganizing books and materials'}, {'time': '20:30 PM', 'location': 'Living Room', 'activity': 'Observing guests from afar'}, {'time': '20:40 PM', 'location': 'Study', 'activity': 'Raising a painting'}, {'time': '20:50 PM', 'location': 'Study', 'activity': 'Tying decorative knots'}, {'time': '21:00 PM', 'location': 'Living Room', 'activity': 'Reorganizing books and materials'}, {'time': '21:10 PM', 'location': 'Bathroom', 'activity': 'Reorganizing books and materials'}, {'time': '21:20 PM', 'location': 'Living Room', 'activity': 'Inflating balloons'}, {'time': '21:30 PM', 'location': 'Living Room', 'activity': 'Tying decorative knots'}, {'time': '21:40 PM', 'location': 'Study', 'activity': 'Tampering with drinks'}, {'time': '21:50 PM', 'location': 'Study', 'activity': 'Taking her dog for a walk'}, {'time': '22:00 PM', 'location': 'Study', 'activity': 'Ripping wippets'}, {'time': '22:10 PM', 'location': 'Study', 'activity': 'Observing guests from afar'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Study', 'activity': 'Reading warning labels'}, {'time': '19:10 PM', 'location': 'Study', 'activity': 'Raising a painting'}, {'time': '19:20 PM', 'location': 'Living Room', 'activity': 'Tying decorative knots'}, {'time': '19:30 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}, {'time': '19:40 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}, {'time': '19:50 PM', 'location': 'Study', 'activity': 'Reading warning labels'}, {'time': '20:00 PM', 'location': 'Dining Room', 'activity': 'Reorganizing books and materials'}, {'time': '20:10 PM', 'location': 'Living Room', 'activity': 'Tying decorative knots'}, {'time': '20:20 PM', 'location': 'Living Room', 'activity': 'Observing guests from afar'}, {'time': '20:30 PM', 'location': 'Living Room', 'activity': 'Observing guests from afar'}, {'time': '20:40 PM', 'location': 'Bathroom', 'activity': 'Reorganizing books and materials'}, {'time': '20:50 PM', 'location': 'Living Room', 'activity': 'Taking her dog for a walk'}, {'time': '21:00 PM', 'location': 'Study', 'activity': 'Observing guests from afar'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Tying decorative knots'}, {'time': '21:20 PM', 'location': 'Kitchen', 'activity': 'Rinsing a glass carefully'}, {'time': '21:30 PM', 'location': 'Pantry', 'activity': 'Tying decorative knots'}, {'time': '21:40 PM', 'location': 'Kitchen', 'activity': 'Raising a painting'}, {'time': '21:50 PM', 'location': 'Dining Room', 'activity': 'Observing guests from afar'}, {'time': '22:00 PM', 'location': 'Kitchen', 'activity': 'Raising a painting'}, {'time': '22:10 PM', 'location': 'Kitchen', 'activity': 'Raising a painting'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Study', 'activity': 'Raising a painting'}, {'time': '19:10 PM', 'location': 'Living Room', 'activity': 'Taking her dog for a walk'}, {'time': '19:20 PM', 'location': 'Living Room', 'activity': 'Reorganizing books and materials'}, {'time': '19:30 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}, {'time': '19:40 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '19:50 PM', 'location': 'Bathroom', 'activity': 'Raising a painting'}, {'time': '20:00 PM', 'location': 'Living Room', 'activity': 'Raising a painting'}, {'time': '20:10 PM', 'location': 'Living Room', 'activity': 'Taking her dog for a walk'}, {'time': '20:20 PM', 'location': 'Dining Room', 'activity': 'Reorganizing books and materials'}, {'time': '20:30 PM', 'location': 'Study', 'activity': 'Observing guests from afar'}, {'time': '20:40 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}, {'time': '20:50 PM', 'location': 'Living Room', 'activity': 'Raising a painting'}, {'time': '21:00 PM', 'location': 'Living Room', 'activity': 'Observing guests from afar'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Raising a painting'}, {'time': '21:20 PM', 'location': 'Study', 'activity': 'Polishing household items'}, {'time': '21:30 PM', 'location': 'Living Room', 'activity': 'Tying decorative knots'}, {'time': '21:40 PM', 'location': 'Study', 'activity': 'Taking her dog for a walk'}, {'time': '21:50 PM', 'location': 'Living Room', 'activity': 'Raising a painting'}, {'time': '22:00 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '22:10 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Living Room', 'activity': 'Observing guests from afar'}, {'time': '19:10 PM', 'location': 'Study', 'activity': 'Taking her dog for a walk'}, {'time': '19:20 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '19:30 PM', 'location': 'Dining Room', 'activity': 'Taking her dog for a walk'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Swapping drinks unnoticed'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Observing guests from afar'}, {'time': '20:00 PM', 'location': 'Living Room', 'activity': 'Bringing in the shopping'}, {'time': '20:10 PM', 'location': 'Living Room', 'activity': 'Raising a painting'}, {'time': '20:20 PM', 'location': 'Study', 'activity': 'Opening letters'}, {'time': '20:30 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}, {'time': '20:40 PM', 'location': 'Study', 'activity': 'Raising a painting'}, {'time': '20:50 PM', 'location': 'Dining Room', 'activity': 'Reorganizing books and materials'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Reorganizing books and materials'}, {'time': '21:10 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}, {'time': '21:20 PM', 'location': 'Living Room', 'activity': 'Retrieving items from storage'}, {'time': '21:30 PM', 'location': 'Study', 'activity': 'Swapping drinks unnoticed'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Reorganizing books and materials'}, {'time': '21:50 PM', 'location': 'Bathroom', 'activity': 'Observing guests from afar'}, {'time': '22:00 PM', 'location': 'Bathroom', 'activity': 'Taking her dog for a walk'}, {'time': '22:10 PM', 'location': 'Living Room', 'activity': 'Retrieving items from storage'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Living Room', 'activity': 'Observing guests from afar'}, {'time': '19:10 PM', 'location': 'Living Room', 'activity': 'Reorganizing books and materials'}, {'time': '19:20 PM', 'location': 'Bathroom', 'activity': 'Taking her dog for a walk'}, {'time': '19:30 PM', 'location': 'Bathroom', 'activity': 'Tying decorative knots'}, {'time': '19:40 PM', 'location': 'Bathroom', 'activity': 'Reorganizing books and materials'}, {'time': '19:50 PM', 'location': 'Living Room', 'activity': 'Raising a painting'}, {'time': '20:00 PM', 'location': 'Dining Room', 'activity': 'Tying decorative knots'}, {'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Observing guests from afar'}, {'time': '20:20 PM', 'location': 'Dining Room', 'activity': 'Reorganizing books and materials'}, {'time': '20:30 PM', 'location': 'Living Room', 'activity': 'Opening letters'}, {'time': '20:40 PM', 'location': 'Living Room', 'activity': 'Taking her dog for a walk'}, {'time': '20:50 PM', 'location': 'Study', 'activity': 'Retrieving items from storage'}, {'time': '21:00 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '21:10 PM', 'location': 'Living Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:20 PM', 'location': 'Study', 'activity': 'Observing guests from afar'}, {'time': '21:30 PM', 'location': 'Study', 'activity': 'Taking her dog for a walk'}, {'time': '21:40 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}, {'time': '21:50 PM', 'location': 'Study', 'activity': 'Raising a painting'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Opening letters'}, {'time': '22:10 PM', 'location': 'Living Room', 'activity': 'Observing guests from afar'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Living Room', 'activity': 'Taking her dog for a walk'}, {'time': '19:10 PM', 'location': 'Study', 'activity': 'Tying decorative knots'}, {'time': '19:20 PM', 'location': 'Living Room', 'activity': 'Raising a painting'}, {'time': '19:30 PM', 'location': 'Study', 'activity': 'Raising a painting'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Ripping wippets'}, {'time': '19:50 PM', 'location': 'Study', 'activity': 'Observing guests from afar'}, {'time': '20:00 PM', 'location': 'Study', 'activity': 'Peeling an orange'}, {'time': '20:10 PM', 'location': 'Living Room', 'activity': 'Taking her dog for a walk'}, {'time': '20:20 PM', 'location': 'Study', 'activity': 'Taking her dog for a walk'}, {'time': '20:30 PM', 'location': 'Study', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:40 PM', 'location': 'Living Room', 'activity': 'Tying decorative knots'}, {'time': '20:50 PM', 'location': 'Living Room', 'activity': 'Inspecting a family heirloom'}, {'time': '21:00 PM', 'location': 'Living Room', 'activity': 'Reorganizing books and materials'}, {'time': '21:10 PM', 'location': 'Study', 'activity': 'Speaking in a high-pitched voice'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Raising a painting'}, {'time': '21:30 PM', 'location': 'Study', 'activity': 'Taking her dog for a walk'}, {'time': '21:40 PM', 'location': 'Study', 'activity': 'Raising a painting'}, {'time': '21:50 PM', 'location': 'Study', 'activity': 'Raising a painting'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Reorganizing books and materials'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Raising a painting'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Living Room', 'activity': 'Taking her dog for a walk'}, {'time': '19:10 PM', 'location': 'Study', 'activity': 'Inspecting wine bottles'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Taking her dog for a walk'}, {'time': '19:30 PM', 'location': 'Dining Room', 'activity': 'Raising a painting'}, {'time': '19:40 PM', 'location': 'Living Room', 'activity': 'Reorganizing books and materials'}, {'time': '19:50 PM', 'location': 'Bathroom', 'activity': 'Tying decorative knots'}, {'time': '20:00 PM', 'location': 'Living Room', 'activity': 'Reading warning labels'}, {'time': '20:10 PM', 'location': 'Study', 'activity': 'Bragging about their Birkin'}, {'time': '20:20 PM', 'location': 'Living Room', 'activity': 'Tampering with drinks'}, {'time': '20:30 PM', 'location': 'Study', 'activity': 'Looking in drawers'}, {'time': '20:40 PM', 'location': 'Study', 'activity': 'Retrieving items from storage'}, {'time': '20:50 PM', 'location': 'Study', 'activity': 'Observing guests from afar'}, {'time': '21:00 PM', 'location': 'Living Room', 'activity': 'Talking about skeet shooting'}, {'time': '21:10 PM', 'location': 'Living Room', 'activity': 'Inspecting a family heirloom'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Bringing in the shopping'}, {'time': '21:30 PM', 'location': 'Living Room', 'activity': 'Raising a painting'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Raising a painting'}, {'time': '21:50 PM', 'location': 'Bathroom', 'activity': 'Observing guests from afar'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Ripping wippets'}, {'time': '22:10 PM', 'location': 'Study', 'activity': 'Bringing in the shopping'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Study', 'activity': 'Inspecting a family heirloom'}, {'time': '19:10 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '19:20 PM', 'location': 'Study', 'activity': 'Reading warning labels'}, {'time': '19:30 PM', 'location': 'Study', 'activity': 'Observing guests from afar'}, {'time': '19:40 PM', 'location': 'Living Room', 'activity': 'Reading warning labels'}, {'time': '19:50 PM', 'location': 'Bathroom', 'activity': 'Reorganizing books and materials'}, {'time': '20:00 PM', 'location': 'Living Room', 'activity': 'Tying decorative knots'}, {'time': '20:10 PM', 'location': 'Study', 'activity': 'Taking her dog for a walk'}, {'time': '20:20 PM', 'location': 'Study', 'activity': 'Polishing household items'}, {'time': '20:30 PM', 'location': 'Study', 'activity': 'Raising a painting'}, {'time': '20:40 PM', 'location': 'Study', 'activity': 'Raising a painting'}, {'time': '20:50 PM', 'location': 'Study', 'activity': 'Taking her dog for a walk'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Returning to mingle with guests'}, {'time': '21:10 PM', 'location': 'Kitchen', 'activity': 'Observing guests from afar'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Reorganizing books and materials'}, {'time': '21:30 PM', 'location': 'Living Room', 'activity': 'Observing guests from afar'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Retrieving items from storage'}, {'time': '21:50 PM', 'location': 'Living Room', 'activity': 'Raising a painting'}, {'time': '22:00 PM', 'location': 'Study', 'activity': 'Tying decorative knots'}, {'time': '22:10 PM', 'location': 'Dining Room', 'activity': 'Ripping wippets'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Study', 'activity': 'Returning to mingle with guests'}, {'time': '19:10 PM', 'location': 'Living Room', 'activity': 'Raising a painting'}, {'time': '19:20 PM', 'location': 'Bathroom', 'activity': 'Observing guests from afar'}, {'time': '19:30 PM', 'location': 'Living Room', 'activity': 'Reorganizing books and materials'}, {'time': '19:40 PM', 'location': 'Study', 'activity': 'Raising a painting'}, {'time': '19:50 PM', 'location': 'Study', 'activity': 'Inflating balloons'}, {'time': '20:00 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}, {'time': '20:10 PM', 'location': 'Living Room', 'activity': 'Opening letters'}, {'time': '20:20 PM', 'location': 'Study', 'activity': 'Observing guests from afar'}, {'time': '20:30 PM', 'location': 'Study', 'activity': 'Observing guests from afar'}, {'time': '20:40 PM', 'location': 'Living Room', 'activity': 'Raising a painting'}, {'time': '20:50 PM', 'location': 'Study', 'activity': 'Tying decorative knots'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Bringing in the shopping'}, {'time': '21:10 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}, {'time': '21:20 PM', 'location': 'Study', 'activity': 'Rinsing a glass carefully'}, {'time': '21:30 PM', 'location': 'Study', 'activity': 'Complaining about TSA going through their purse'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Talking about skeet shooting'}, {'time': '21:50 PM', 'location': 'Living Room', 'activity': 'Tying decorative knots'}, {'time': '22:00 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}, {'time': '22:10 PM', 'location': 'Living Room', 'activity': 'Taking her dog for a walk'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Study', 'activity': 'Observing guests from afar'}, {'time': '19:10 PM', 'location': 'Study', 'activity': 'Raising a painting'}, {'time': '19:20 PM', 'location': 'Living Room', 'activity': 'Raising a painting'}, {'time': '19:30 PM', 'location': 'Living Room', 'activity': 'Raising a painting'}, {'time': '19:40 PM', 'location': 'Study', 'activity': 'Raising a painting'}, {'time': '19:50 PM', 'location': 'Study', 'activity': 'Tying decorative knots'}, {'time': '20:00 PM', 'location': 'Living Room', 'activity': 'Tying decorative knots'}, {'time': '20:10 PM', 'location': 'Study', 'activity': 'Looking in drawers'}, {'time': '20:20 PM', 'location': 'Living Room', 'activity': 'Reading warning labels'}, {'time': '20:30 PM', 'location': 'Living Room', 'activity': 'Observing guests from afar'}, {'time': '20:40 PM', 'location': 'Study', 'activity': 'Observing guests from afar'}, {'time': '20:50 PM', 'location': 'Living Room', 'activity': 'Raising a painting'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Tying decorative knots'}, {'time': '21:10 PM', 'location': 'Study', 'activity': 'Polishing household items'}, {'time': '21:20 PM', 'location': 'Study', 'activity': 'Raising a painting'}, {'time': '21:30 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}, {'time': '21:40 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}, {'time': '21:50 PM', 'location': 'Dining Room', 'activity': 'Reorganizing books and materials'}, {'time': '22:00 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}, {'time': '22:10 PM', 'location': 'Living Room', 'activity': 'Tying decorative knots'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Living Room', 'activity': 'Observing guests from afar'}, {'time': '19:10 PM', 'location': 'Bathroom', 'activity': 'Reorganizing books and materials'}, {'time': '19:20 PM', 'location': 'Living Room', 'activity': 'Taking her dog for a walk'}, {'time': '19:30 PM', 'location': 'Living Room', 'activity': 'Inspecting a family heirloom'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Bragging about their Birkin'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Reorganizing books and materials'}, {'time': '20:00 PM', 'location': 'Kitchen', 'activity': 'Whittling a stick'}, {'time': '20:10 PM', 'location': 'Pantry', 'activity': 'Raising a painting'}, {'time': '20:20 PM', 'location': 'Kitchen', 'activity': 'Tying decorative knots'}, {'time': '20:30 PM', 'location': 'Pantry', 'activity': 'Rinsing a glass carefully'}, {'time': '20:40 PM', 'location': 'Kitchen', 'activity': 'Raising a painting'}, {'time': '20:50 PM', 'location': 'Pantry', 'activity': 'Taking her dog for a walk'}, {'time': '21:00 PM', 'location': 'Pantry', 'activity': 'Observing guests from afar'}, {'time': '21:10 PM', 'location': 'Pantry', 'activity': 'Taking her dog for a walk'}, {'time': '21:20 PM', 'location': 'Kitchen', 'activity': 'Reorganizing books and materials'}, {'time': '21:30 PM', 'location': 'Pantry', 'activity': 'Tying decorative knots'}, {'time': '21:40 PM', 'location': 'Pantry', 'activity': 'Raising a painting'}, {'time': '21:50 PM', 'location': 'Kitchen', 'activity': 'Reorganizing books and materials'}, {'time': '22:00 PM', 'location': 'Dining Room', 'activity': 'Tying decorative knots'}, {'time': '22:10 PM', 'location': 'Study', 'activity': 'Raising a painting'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Study', 'activity': 'Raising a painting'}, {'time': '19:10 PM', 'location': 'Study', 'activity': 'Observing guests from afar'}, {'time': '19:20 PM', 'location': 'Study', 'activity': 'Taking her dog for a walk'}, {'time': '19:30 PM', 'location': 'Living Room', 'activity': 'Reorganizing books and materials'}, {'time': '19:40 PM', 'location': 'Study', 'activity': 'Tying decorative knots'}, {'time': '19:50 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}, {'time': '20:00 PM', 'location': 'Study', 'activity': 'Taking her dog for a walk'}, {'time': '20:10 PM', 'location': 'Study', 'activity': 'Observing guests from afar'}, {'time': '20:20 PM', 'location': 'Living Room', 'activity': 'Tying decorative knots'}, {'time': '20:30 PM', 'location': 'Living Room', 'activity': 'Taking her dog for a walk'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Tying decorative knots'}, {'time': '20:50 PM', 'location': 'Study', 'activity': 'Raising a painting'}, {'time': '21:00 PM', 'location': 'Dining Room', 'activity': 'Taking her dog for a walk'}, {'time': '21:10 PM', 'location': 'Dining Room', 'activity': 'Inspecting wine bottles'}, {'time': '21:20 PM', 'location': 'Living Room', 'activity': 'Reorganizing books and materials'}, {'time': '21:30 PM', 'location': 'Living Room', 'activity': 'Reorganizing books and materials'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Reorganizing books and materials'}, {'time': '21:50 PM', 'location': 'Bathroom', 'activity': 'Returning to mingle with guests'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Observing guests from afar'}, {'time': '22:10 PM', 'location': 'Living Room', 'activity': 'Serving drinks and chatting with guests'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Living Room', 'activity': 'Complaining about TSA going through their purse'}, {'time': '19:10 PM', 'location': 'Living Room', 'activity': 'Taking her dog for a walk'}, {'time': '19:20 PM', 'location': 'Study', 'activity': 'Opening a safe'}, {'time': '19:30 PM', 'location': 'Living Room', 'activity': 'Inspecting wine bottles'}, {'time': '19:40 PM', 'location': 'Study', 'activity': 'Tying decorative knots'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Reorganizing books and materials'}, {'time': '20:00 PM', 'location': 'Kitchen', 'activity': 'Bringing in the shopping'}, {'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Observing guests from afar'}, {'time': '20:20 PM', 'location': 'Kitchen', 'activity': 'Taking her dog for a walk'}, {'time': '20:30 PM', 'location': 'Pantry', 'activity': 'Swapping drinks unnoticed'}, {'time': '20:40 PM', 'location': 'Kitchen', 'activity': 'Observing guests from afar'}, {'time': '20:50 PM', 'location': 'Pantry', 'activity': 'Observing guests from afar'}, {'time': '21:00 PM', 'location': 'Pantry', 'activity': 'Reorganizing books and materials'}, {'time': '21:10 PM', 'location': 'Kitchen', 'activity': 'Polishing household items'}, {'time': '21:20 PM', 'location': 'Pantry', 'activity': 'Reorganizing books and materials'}, {'time': '21:30 PM', 'location': 'Kitchen', 'activity': 'Reorganizing books and materials'}, {'time': '21:40 PM', 'location': 'Dining Room', 'activity': 'Tying decorative knots'}, {'time': '21:50 PM', 'location': 'Study', 'activity': 'Observing guests from afar'}, {'time': '22:00 PM', 'location': 'Study', 'activity': 'Tying decorative knots'}, {'time': '22:10 PM', 'location': 'Living Room', 'activity': 'Observing guests from afar'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Study', 'activity': 'Tying decorative knots'}, {'time': '19:10 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}, {'time': '19:20 PM', 'location': 'Living Room', 'activity': 'Tying decorative knots'}, {'time': '19:30 PM', 'location': 'Living Room', 'activity': 'Taking her dog for a walk'}, {'time': '19:40 PM', 'location': 'Living Room', 'activity': 'Taking her dog for a walk'}, {'time': '19:50 PM', 'location': 'Dining Room', 'activity': 'Observing guests from afar'}, {'time': '20:00 PM', 'location': 'Dining Room', 'activity': 'Peeling an orange'}, {'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Serving drinks and chatting with guests'}, {'time': '20:20 PM', 'location': 'Pantry', 'activity': 'Taking her dog for a walk'}, {'time': '20:30 PM', 'location': 'Kitchen', 'activity': 'Observing guests from afar'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Taking her dog for a walk'}, {'time': '20:50 PM', 'location': 'Kitchen', 'activity': 'Reorganizing books and materials'}, {'time': '21:00 PM', 'location': 'Pantry', 'activity': 'Tying decorative knots'}, {'time': '21:10 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '21:20 PM', 'location': 'Dining Room', 'activity': 'Observing guests from afar'}, {'time': '21:30 PM', 'location': 'Living Room', 'activity': 'Reading a novel quietly'}, {'time': '21:40 PM', 'location': 'Living Room', 'activity': 'Reorganizing books and materials'}, {'time': '21:50 PM', 'location': 'Living Room', 'activity': 'Tying decorative knots'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Observing guests from afar'}, {'time': '22:10 PM', 'location': 'Bathroom', 'activity': 'Reorganizing books and materials'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Living Room', 'activity': 'Tying decorative knots'}, {'time': '19:10 PM', 'location': 'Study', 'activity': 'Raising a painting'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Peeling an orange'}, {'time': '19:30 PM', 'location': 'Dining Room', 'activity': 'Observing guests from afar'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Serving drinks and chatting with guests'}, {'time': '19:50 PM', 'location': 'Living Room', 'activity': 'Taking her dog for a walk'}, {'time': '20:00 PM', 'location': 'Living Room', 'activity': 'Peeling an orange'}, {'time': '20:10 PM', 'location': 'Living Room', 'activity': 'Reorganizing books and materials'}, {'time': '20:20 PM', 'location': 'Dining Room', 'activity': 'Tying decorative knots'}, {'time': '20:30 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}, {'time': '20:40 PM', 'location': 'Dining Room', 'activity': 'Observing guests from afar'}, {'time': '20:50 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}, {'time': '21:00 PM', 'location': 'Study', 'activity': 'Inspecting wine bottles'}, {'time': '21:10 PM', 'location': 'Study', 'activity': 'Tying decorative knots'}, {'time': '21:20 PM', 'location': 'Study', 'activity': 'Taking her dog for a walk'}, {'time': '21:30 PM', 'location': 'Study', 'activity': 'Reading a novel quietly'}, {'time': '21:40 PM', 'location': 'Study', 'activity': 'Washing up after handling items'}, {'time': '21:50 PM', 'location': 'Living Room', 'activity': 'Raising a painting'}, {'time': '22:00 PM', 'location': 'Living Room', 'activity': 'Taking her dog for a walk'}, {'time': '22:10 PM', 'location': 'Study', 'activity': 'Ripping wippets'}]}, {'suspect_statement': [{'time': '19:00 PM', 'location': 'Study', 'activity': 'Taking her dog for a walk'}, {'time': '19:10 PM', 'location': 'Dining Room', 'activity': 'Bringing in the shopping'}, {'time': '19:20 PM', 'location': 'Dining Room', 'activity': 'Raising a painting'}, {'time': '19:30 PM', 'location': 'Living Room', 'activity': 'Observing guests from afar'}, {'time': '19:40 PM', 'location': 'Study', 'activity': 'Observing guests from afar'}, {'time': '19:50 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}, {'time': '20:00 PM', 'location': 'Study', 'activity': 'Reorganizing books and materials'}, {'time': '20:10 PM', 'location': 'Dining Room', 'activity': 'Observing guests from afar'}, {'time': '20:20 PM', 'location': 'Living Room', 'activity': '
PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}, {'time': '19:40 PM', 'location': 'Dining Room', 'activity': 'Reading warning labels'}, {'time': '20:20 PM', 'location': 'Kitchen', 'activity': 'Reading warning labels'}]}, 'Tyler': {'witness_reliability': 0.47345896052887254, 'observations': [{'time': '20:10 PM', 'location': 'Kitchen', 'activity': 'Looking in drawers'}, {'time': '21:20 PM', 'location': 'Pantry', 'activity': 'Looking in drawers'}, {'time': '21:50 PM', 'location': 'Pantry', 'activity': 'Ripping wippets'}]}}}}

# Print Resulting Data
print("ALIAS DATA")
pprint.pprint(alias_data)

print("SUSCPECT DATA")
pprint.pprint(suspect_data)

# %% [markdown]
# ## Task 2: Decision Tree (7 pts)

# %% [markdown]
# ### *Story Progression*
#
# Looking through the data you have, you realize there's a lot of repeated, overlapping activities and this reminds you of categorical data. You wonder if you could somehow set up a decision tree with the classes being the aliases and then try and match the suspects statements against them!

# %% [markdown]
# ### *Task Description*
#
# Train a decision tree classifier to match suspects to the aliases.
# You'll have to do some feature engineering to get the categorial data we have into a format that can be used by the decision tree.
#
# 1. Define activity to weapon mapping
#    * Some of the activities seem related to the weapons found at the party, I wonder if we can use that to improve our decision tree?
#
# 2. Feature Engineering / Extraction Function:
#    * We need to somehow turn all of the data we were given into a format that can be used by the decision tree
#    * Use activities that suggest a weapon that matches each alias
#
# 3. Prepare Data
#    * Run feature extraction function in your alias and suspect data
#
# 4. Train decision tree for classification
#    * Hint: use `sklearn.tree`
#
# 5. Test decision tree classifier and print results
#    * Note: All code for printing results is provided to make output format consistent among students
#
# 6. Store decision tree results to be used later in Bayesian reasoning task
#    * Note: This step is done for the students to make sure data formats align between tasks to later be used in Bayesian reasoning

# %% [markdown]
# ### *Code Implemetation*

# %%
# TODO: Some of the activities seem related to the weapons found at the party, I wonder if we can use that to improve our decision tree.
# TODO: Define Activity-to-Weapon Mapping
# Note: There should be 3 activities per weapon

activity_weapon_mapping = {
    'Inflating balloons': 'Gas',
    'Ripping wippets': 'Gas',
    #TODO: Add a third Gas activity

    'Whittling a stick': 'Knife',
    'Peeling an orange': 'Knife',
    'Opening letters': 'Knife',

    'Tampering with drinks': 'Poison',
    'Rinsing a glass carefully': 'Poison',
    #TODO: Add a third Poison activity

    'Tying decorative knots': 'Rope',
    'Raising a painting': 'Rope',
    'Taking her dog for a walk': 'Rope',

    'Inspecting a family heirloom': 'Firearm',
    'Opening a safe': 'Firearm',
    'Talking about skeet shooting': 'Firearm',

    'Bragging about their Birkin': 'Bag',
    'Complaining about TSA going through their purse': 'Bag',
    #TODO: Add a third Bag activity
}

# TODO: finish feature extraction function
def extract_features(data, is_alias=True):
    '''
    Function converts the categorical data we have into numerical data for the decision tree
    '''

    rooms = ['Study', 'Dining Room', 'Kitchen', 'Pantry', 'Living Room', 'Bathroom']    # List of possible rooms where a suspect might have been
    weapons = ['Poison', 'Knife', 'Gas', 'Rope', 'Bag', 'Firearm']                      # List of possible weapons

    features = {}                                  # Dictionary to store extracted/calculated features

    room_time = {room: 0 for room in rooms}        # Dictionary to track time in each room, start at 0
    activities = []                                # List to store activities done by suspect

    total_time = 0                                 # Keep track of total observations suspet has

    # TODO: Count the amount of times the suspect or alias visits each room and a list of activities they do

    # TODO: Calculate the percentage of time the suspect or alias spends in each room

    # TODO: Create features indicating if an activity they've done suggests a weapon
    
    return features

# %%
### PREPARE DATA ###

# Imports
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_text

alias_features_dict = {}                                                    # Make empty dict to store extracted features for each alias
for alias_name, alias_samples in alias_data.items():                        # Loop through each alias in alias_data
    alias_features_dict[alias_name] = []                                        # Make empty list for each alias to store extracted features
    for alias_sample in alias_samples:                                          # Loop through alias statements belonging to the same person
        features = extract_features(alias_sample, is_alias=True)                    # Call extract_features function
        alias_features_dict[alias_name].append(features)                            # Append extracted features dictionary

suspect_features_dict = {}                                                  # empty dict to store extracted features for each suspect
for suspect, data in suspect_data.items():                                  # Loop through each suspect in suspect data
    features = extract_features(data, is_alias=False)                           # Call extract features function
    suspect_features_dict[suspect] = features                                   # Store extracted features in suspect_features_dict

# %%
### MAKE DECISION TREE, TRAIN DECISION TREE, TEST DECISION TREE ###

# TODO: Define training and testing data (alias features)

# TODO: Train Decision Tree Classifier
# use arguments criterion='entropy', random_state=42, max_depth=4, min_samples_split=4

# EXTRA: Print the decision tree structure
#tree_rules = export_text(clf, feature_names=[f'time_in_{room}' for room in rooms] + [f'suggests_{weapon}' for weapon in weapons])
#print(tree_rules)

X_test = [list(x.values()) for x in suspect_features_dict.values()]
probabilities = clf.predict_proba(X_test)                 # returns a 2D matrix of probabilities
                                                          # each row is a suspect, each col is the probability that the suspect matches one of the aliases

# Print Results
print("\nProbability of Each Suspect Matching Each Alias:\n")
print(f"{clf.classes_}")

for suspect_name, probs in zip(suspect_features_dict.keys(), probabilities):
    formatted_probs = [f"{v:.4f}" for v in probs]
    print(f'{suspect_name}: {formatted_probs}')

# Store decision tree results to be used later in bayesian reasoning (Task 5)
aliases = list(clf.classes_)
decision_tree_results = {s_n: p for s_n, p in zip(suspect_features_dict.keys(), probabilities)}
# Notes:
#    dict contains suspect names as keys and their corresponding probability distributions as values
#    aka each suspect has list of probs (one prob per alias) for how likely it is that said suspect matches said alias

# %% [markdown]
# ### Expected Output:
#
# ```
# Probability of Each Suspect Matching Each Alias:
#
# ['Colonel Mustard' 'Miss Scarlet' 'Mr. Green' 'Mrs. Peacock' 'Mrs. White' 'Professor Plum']
# Tom Lohman: ['0.5000', '0.0000', '0.0000', '0.5000', '0.0000', '0.0000']
# Jack Mangione: ['0.0000', '0.0000', '0.0000', '0.0000', '0.0000', '1.0000']
# Sophia Noonan: ['0.0000', '0.9412', '0.0000', '0.0000', '0.0000', '0.0588']
# Olivia Zino: ['0.0000', '0.2000', '0.0000', '0.0000', '0.8000', '0.0000']
# Professor Theisen: ['0.0000', '0.0000', '0.0000', '1.0000', '0.0000', '0.0000']
# Cesar Cervera: ['0.0000', '0.0000', '0.8636', '0.0000', '0.0455', '0.0909']
# ```

# %% [markdown]
# ### *Short Answer Questions*
#
#
# 1. Why are we using criterion='entropy'? Explain what “entropy” means in this context and what the tree is maximizing at each split.
#
#    * Answer:
#
#
#
# 2. Do we need to scale or normalize our features for a decision tree? Why or why not?
#
#    * Answer:

# %% [markdown]
# ## Task 3: Hidden Markov Model (7 pts)

# %% [markdown]
# ### *Story Progression*
#
# Nice! We've got a decision tree that can classify the suspects into the aliases! However lets try and get some more evidence before we make a final decision. The decision tree makes use of the time spent in rooms, but it doesn't consider the paths the suspects take between the rooms. Suddenly inspiration strikes! You recall learning about Hidden Markov Models in class and think that maybe you could use them to get some more evidence!
#
# The police have acquired a blueprint of the estate and based on visitor data the likelihood that a person moves between rooms.
#
# <img src="https://raw.githubusercontent.com/nd-cse-30124-sp25/nd-cse-30124-sp25.github.io/refs/heads/main/static/img/estate.png" alt="Estate" style="width: 60%; max-width: 800px; height: auto;">
#
# **Note:** I am not an artist don't laugh!

# %% [markdown]
# ### *Task Description*
#
# 1. Create a blueprint JSON file that gives the transition probabilities between rooms in the estate. Name the file blueprint.json The format should be as follows:
# ```
# "rooms": {
#     "ROOM NAME": {"id": "ROOM ID", "adjacent_to": ["NEIGHBOR 1", "NEIGHBOR 2"]}
#     },
# "transition_probabilities": {
#     "ROOM ID": {
#         "NEIGHBOR 1 ID": 0.4,
#         "NEIGHBOR 2 ID": 0.4,
#         "ROOM ID": 0.2
#     }
# }
# ```
#
#
#    * The transition probabilities are given below:
#       * Study:
#          * Dining Room: 0.3
#          * Living Room: 0.3
#          * Study: 0.4
#       * Dining Room:
#          * Kitchen: 0.25
#          * Study: 0.25
#          * Living Room: 0.25
#          * Dining Room: 0.25
#       * Kitchen:
#          * Dining Room: 0.4
#          * Pantry: 0.4
#          * Kitchen: 0.2
#       * Pantry:
#          * Kitchen: 0.8
#          * Pantry: 0.2
#       * Living Room:
#          * Study: 0.25
#          * Dining Room: 0.25
#          * Bathroom: 0.25
#          * Living Room: 0.25
#       * Bathroom:
#          * Living Room: 0.7
#          * Bathroom: 0.3
#
# 2. Load in blueprint.json to be used in the HMM (or define a blueprint dictionary directly)
#
# 3. Using a hidden markov model, find the most likely path for a suspect given the GPS data and witness statements
#
# 4. Compare the suspect's alleged path from their statement you collected to the most likely path found by the HMM

# %% [markdown]
# ### *Code Implemetation*

# %%
# Imports
import numpy as np
from typing import List, Dict, Tuple
from collections import defaultdict

# Load blueprint.json
with open('/content/drive/MyDrive/Intro To AI/Homeworks/HW02/blueprint.json', 'r') as f:
    blueprint = json.load(f)

# Alternatlively, make bluebrint dictionary directly:
# TODO: Create the blueprint dictionary structure
blueprint = {
    "rooms": {
        
    },
    "transition_probabilities": {
        
    }
}

locations = blueprint['rooms']
n_states = len(locations)

initial = np.ones(n_states) / n_states

def get_statements(suspect):
    """Return a list of {'time': ..., 'location': ...} dicts for this suspect."""
    # Case A: suspect is a dict with the statements directly
    if isinstance(suspect, dict) and 'suspect_statement' in suspect:
        return suspect['suspect_statement']

    # Case B: suspect is a list of dicts (take the first record or merge)
    if isinstance(suspect, list) and suspect and isinstance(suspect[0], dict):
        if 'suspect_statement' in suspect[0]:
            return suspect[0]['suspect_statement']
        # Or maybe the list *is* the statements already:
        if 'time' in suspect[0] and 'location' in suspect[0]:
            return suspect

    # Fallback: empty
    return []

# %%
def weight_room_matrix(time: str, gps_data: List[Dict], witness_statements: Dict[str, Dict]) -> np.ndarray:
    """
    Create emission probability matrix using objective evidence (GPS and witnesses).
    """

    # Start with uniform distribution
    emission = np.ones(n_states) / n_states

    # TODO: Weight based on GPS evidence
    # Conceptually:
    #    Check if there is GPS data for specified time
    #    If yes, then:
    #        get location and signal strengh
    #        reduce the prob of all rooms based on inverse of signal strength
    #        increase the prob of room matching GPS data based on signal strength

    # TODO: Weight based on witness evidence
    # Conceptually:
    #     Check witness statement for a given time
    #     Retrieve the reliability of witness, adjust emission matrix probs
    #     Probs are adjusted by:
    #         Reduce the likelihood of all rooms by (1 - reliability) and
    #         Increase the prob of the room where witness saw the suspect based on reliability measure

    # TODO: Normalize
    emission /= np.sum(emission)

    return emission

# %% [markdown]
# ### *Short Answer Questions*

# %%
# -------------------------------------
# Step 3: Write viterbi function
# -------------------------------------
def viterbi(suspect_data: Dict, timestamps: List[str]) -> Tuple[List[str], float]:
    """
    Use Viterbi algorithm to find most likely sequence of true locations.
    Also returns the probability of the sequence.
    """
    # -------------------------------------
    # Step 3a: Get ready for forward pass
    #     1. Set up total_timesteps and num_rooms
    #     2. Initialize V and backptr matricies
    #     3. Compute emmissions probabilites matrix
    #     4. Initialize first timestep
    # -------------------------------------

    # TODO: Initialize total_timesteps, num_rooms, and matrices
    
    # Create emission matrices for all timestamps
    emissions = []
    for t in timestamps:
        emission_t = weight_room_matrix(t, suspect_data['gps_data'], suspect_data['witness_statements'])
        emissions.append(emission_t)

    # TODO: Initialize first timestep
    # Note: first time step (time 0) probs are initialized using initial state distribution and emission matrix for first time step

    # -------------------------------------
    # Step 3b: Do forward pass
    #     1. Iterate through each time step
    #     2. For each room, consider all possible previous rooms (adjacent rooms)
    #     3. Compute the prob of arriving in room from any adjacent room
    #     4. Store the best previous state in backptr (to use for backtracking later)
    #     5. Updates the Viterbi matrix (V) with the highest probability
    # -------------------------------------

    # -------------------------------------
    # Step 3c: Backtrack to reconstruct path
    #   1. Find most likely ending room
    #   2. Backtrack through the backptr matrix to reconstruct the path
    #   3. Reverse reconstructed path to correct order
    #   4. Convert room IDs to room names
    #   5. Compute the prob of sequence
    #   6. Return path and its probability
    # -------------------------------------

    # TODO: Initialize the path
    # Conceptually:
    #   V[-1] refers to the last row of the Viterbi matrix (contains the log probabilities of the suspect being in each room at the last time step)
    #   np.argmax(V[-1]) finds the index of the room with the highest probability.
    #   So current gets initialized to most likely final state and then appended to the path as the starting point

    # TODO: Reconstruct the path
    # Conceptually:
    #     traverse the backpointer matrix (backptr) in reverse to reconstruct the most likely path
    #     loop starts from the second-to-last time step (total_timesteps - 1) and goes backward to 1
    #.    backptr[time_step, current] gives the most likely previous room at time_step
    #     current is updated to this previous room and then added to the path

    # TODO: Reverse path and convert indicies to room names
    # Conceptually:
    #    Since we were backtracking from the last time step to the first, the path list is in reverse order.
    #    path.reverse() puts it in chronological order
    #    Then we need to convert the numerical room indices in reconstructed path back to their names using blueprint

    # TODO: Calculate sequence probability
    # Conceptually:
    #     V[-1] contains the log probs of ending in each room at the last time step
    #     np.max(V[-1]) gives the highest log prob
    #     np.exp(...) converts it back from log prob to actual prob.

    return room_path, sequence_prob

# %%
### Analyze Suspects Paths using HMM ###

# Get number of states in HMM
locations = blueprint['rooms']
n_states = len(locations)

# Set up initial state distribution for HMM
initial = np.ones(n_states) / n_states

movement_results = {}

print("\nHMM Path Analysis:")
print("=" * 50)

# Loop through each suspect in dataset
for suspect_name, suspect in suspect_data.items():
    # Get all timestamps in chronological order (hint: sort timestamps to ensure chronological order)
    timestamps = []
    for entry in suspect['suspect_statement']:
        timestamps.append(entry['time'])
    timestamps.sort()

    # Run Viterbi to get most likely true path using GPS data and witness statements
    true_path, path_prob = viterbi(
        {
            'gps_data': suspect['gps_data'],
            'witness_statements': suspect['witness_statements']
        },
        timestamps
    )

    # Compare the true path (from Viterbi) and the suspect's stated path
    # Count the number of matches where the suspect's statement aligns with the computed true path
    # TODO: Get suspects stated path

    # TODO: Calculate matches between true and stated paths
    #     hint: Compare the true path (from Viterbi) and the suspect's stated path by
    #           counting the number of matches where the suspect's statement aligns with the computed true path

    agreement = matches / len(true_path)

    print(f"\n{suspect_name}:")
    print(f'\tAgreement of Statement Path with HMM Path: {agreement}, Number of Contradictions: {len(true_path) - matches}')

    path_agreement = {
        'path_probability': path_prob,
        'statement_agreement': agreement,
        'num_contradictions': len(true_path) - matches
    }

    movement_results[suspect_name] = path_agreement

# %% [markdown]
# ### Expected Output:
#
# ```
# HMM Path Analysis:
# ==================================================
#
# Tom Lohman:
# 	Agreement of Statement Path with HMM Path: 0.15, Number of Contradictions: 17
#
# Jack Mangione:
# 	Agreement of Statement Path with HMM Path: 0.4, Number of Contradictions: 12
#
# Sophia Noonan:
# 	Agreement of Statement Path with HMM Path: 0.1, Number of Contradictions: 18
#
# Olivia Zino:
# 	Agreement of Statement Path with HMM Path: 0.15, Number of Contradictions: 17
#
# Professor Theisen:
# 	Agreement of Statement Path with HMM Path: 0.05, Number of Contradictions: 19
#
# Cesar Cervera:
# 	Agreement of Statement Path with HMM Path: 0.0, Number of Contradictions: 20
# ```

# %% [markdown]
# ### *Short Answer Questions*
#
#
# 1. Why do we use np.log around our probabilities and add them instead of multiplying them?
#
#    * Answer:
#
#
#
# 2. How do we create the emissions matrix?
#
#    * Answer:
#
#
# ### *HMM Results*
#
# Looks like we have a lot of lying suspects, but one seems to be lying more than the others. The evidence is beginning to stack up against Mr. Cervera!

# %% [markdown]
# ## Task 4: Final Bayesian Analysis (4 pts)

# %% [markdown]
# ### *Story Progression*
#
# *Nice*, now we have two pieces of evidence that we can use to match the suspects to the aliases! If only there were some way to combine them. As you finish your drink you think back to class and remember that you can use Bayesian reasoning to combine the evidence! With the mix of your knowledge of bayesian reasoning and python programming skills, hopefully we be able to figure out who was who!

# %% [markdown]
# ### *Task Description*
#
# Perform a final Bayesian analysis to combine the evidence from the decision tree and the Hidden Markov Model to get the likelihood of each suspect matching each alias.
#
#
# 1. Define a function that combines the evidence from the decision tree and the HMM to give an output containing a mapping of the normalized posterior probability distribution over all aliases for each suspect.
#
#
# 2. Run the function previously defined in step 1 on your evidence
#
# 3. Print the results

# %% [markdown]
# ### *Code Implemetation*

# %%
def combine_evidence_bayesian(aliases, decision_tree_results, hmm_results) -> Dict[str, Dict]:
    """
    Combine all evidence, assuming that whomever is Mr. Green is lying!

    P(Alias|Evidence) ∝ P(Alias|Activities) * P(Alias|Truthfulness)
    """
    final_results = {}

    # We can assume that whomever is Mr. Green is lying
    # So low statement match with highest likelihood path → higher probability of being Mr. Green

    # TODO: Iterate through each suspect and calculate posterior probabilities

        # TODO: Retrieve decision tree probabilities for the current suspect

        # TODO: Retrieve path agreement score from the HMM results

        # TODO: For each alias, combine decision tree and HMM evidence

        # TODO: Normalize posteriors

    return final_results

# Call combine_evidence_bayesian to get final probabilities for each suspect being each alias
final_results = combine_evidence_bayesian(aliases, decision_tree_results, movement_results)

# Print Results
for suspect, results in final_results.items():
    print(f"{suspect}:")
    for alias, prob in results.items():
        print(f"  {alias}: {prob:.3f}")

# %% [markdown]
# ### Expected Results:
#
# ```
# Cesar Cervera:
#   Colonel Mustard: 0.000
#   Miss Scarlet: 0.000
#   Mr. Green: 1.000
#   Mrs. Peacock: 0.000
#   Mrs. White: 0.000
#   Professor Plum: 0.000
# Jack Mangione:
#   Colonel Mustard: 0.000
#   Miss Scarlet: 0.000
#   Mr. Green: 0.000
#   Mrs. Peacock: 0.000
#   Mrs. White: 0.000
#   Professor Plum: 1.000
# Tom Lohman:
#   Colonel Mustard: 0.500
#   Miss Scarlet: 0.000
#   Mr. Green: 0.000
#   Mrs. Peacock: 0.500
#   Mrs. White: 0.000
#   Professor Plum: 0.000
# Olivia Zino:
#   Colonel Mustard: 0.000
#   Miss Scarlet: 0.200
#   Mr. Green: 0.000
#   Mrs. Peacock: 0.000
#   Mrs. White: 0.800
#   Professor Plum: 0.000
# Sophia Noonan:
#   Colonel Mustard: 0.000
#   Miss Scarlet: 0.941
#   Mr. Green: 0.000
#   Mrs. Peacock: 0.000
#   Mrs. White: 0.000
#   Professor Plum: 0.059
# Professor Theisen:
#   Colonel Mustard: 0.000
#   Miss Scarlet: 0.000
#   Mr. Green: 0.000
#   Mrs. Peacock: 1.000
#   Mrs. White: 0.000
#   Professor Plum: 0.000
# ```

# %% [markdown]
# ## *Final Story Progression: Success!!*

# %% [markdown]
# We did it, it seems extremely likely that Cesar Cervera is Mr. Green! You quickly call up Detective Caulfield and explain your findings. He laughs at you. It seems that a purely statistical analysis isn't going to be enough for the authorities to make a warrant. You pour yourself another drink and start brainstorming other ways to find more conclusive evidence.
